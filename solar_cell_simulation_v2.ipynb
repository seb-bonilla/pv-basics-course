# %% [markdown]
# ## Running this notebook in Google Colab
#
# This notebook can be run in Google Colab, but it needs a few Python packages and a helper file `pv_cell_functions.py`.
#
# Before running the simulation, make your own copy in Google Drive, select a Python 3 runtime, and click **Connect** in the top-right corner.
#
# Run the setup cells below first. The first setup cell installs DEVSIM and the other Python libraries used in this notebook. The next cell downloads `pv_cell_functions.py` from this GitHub repository so that it can be imported and used later from inside your copy of this Colab notebook.
#
# After the setup is complete, work through the notebook from top to bottom, with the lecturer.

# %%
# Install the packages required for the simulation
# %pip install -q devsim numpy matplotlib pandas plotly pvlib

# %% [markdown]
# # Semiconductor Devices Simulations with DEVSIM
#
# This notebook is an introduction to semiconductor device simulation using **DEVSIM**, an open-source Technology Computer-Aided Design (TCAD) simulator. We  explain each stage of the simulation process, connecting the underlying semiconductor physics with the numerical methods used to solve the governing equations.
#
# Our goal is to simulate the **current–voltage (I–V) characteristics** of semiconductor devices. Along the way, we will examine how physical models, material properties, mesh generation, numerical discretization, and nonlinear equation solving work together to predict device behavior.
#
# **Why Study Device Simulations?**:  Modern semiconductor devices are rarely designed by fabrication alone. Instead, engineers first create numerical models that predict device performance before a single wafer is processed.
#
# Technology Computer-Aided Design (TCAD) enables engineers and researchers to
#
# - understand device physics,
# - optimize semiconductor structures,
# - investigate new materials,
# - evaluate design tradeoffs, and
# - predict electrical performance before fabrication.
#
# ## Importing the Required Libraries
#
# The first step is to import the Python libraries needed for this simulation.
#
# - **DEVSIM** provides the semiconductor device simulator and the numerical solver used throughout the notebook.
# - **NumPy** is used for numerical calculations and working with arrays.
# - **Matplotlib** is used to create plots of the simulation results, such as the current–voltage (I–V) curve.
# - **Pandas** is used to organize and analyze simulation data in tables.
#
# We then display the installed **DEVSIM version** to verify which version of the simulator is being used.
#
# Next, we import the specific DEVSIM functions needed to solve the device equations, apply voltages, and extract quantities such as carrier densities and terminal currents.
#
# Finally, we import two helper modules:
#
# - **`simple_physics`** contains commonly used semiconductor physics models provided with DEVSIM.
# - **`pv_cell_functions`** contains reusable functions that set up the diode geometry, material properties, doping profiles, and physical equations, allowing us to focus on understanding the simulation rather than rewriting standard setup code.

# %%
# Colab needs the helper module; a local run uses the file beside this notebook
try:
    import google.colab
    # !wget -q https://raw.githubusercontent.com/seb-bonilla/pv-basics-course/main/pv_cell_functions.py -O pv_cell_functions.py
    print('Downloaded pv_cell_functions.py')
except ImportError:
    print('Using local pv_cell_functions.py')
# Out:
# Downloaded pv_cell_functions.py

# %%
# we begin with importing the necessary libraries

import devsim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# mpl.rcParams["font.family"] = "Arial"
mpl.rcParams["font.size"] = 14

# and we can check the version of devsim we are using
print("DEVSIM version:", devsim.__version__)
# Out:
# DEVSIM version: 2.10.1

# %%
# we now import the necessary functions from devsim
from devsim import (
    get_contact_current,
    get_edge_model_values,
    get_node_model_values,
    set_parameter,
    solve,
)

import devsim.python_packages.simple_physics as simple_physics

# and the key underlying functions for a diode simulation
import pv_cell_functions as pv_cell

# %% [markdown]
# ### 1. Doped Silicon Bar
#
# Consider a rectangular silicon bar with a metal contact at each end. DEVSIM applies a voltage along its length and calculates the current. Increasing the n-type doping adds mobile electrons, so the bar conducts more current at the same voltage.
#
# For a bar of length $L$, width $w$, and height $h$, the cross-sectional area is $A=wh$ and
#
# $$R=\rho\frac{L}{A}, \qquad \sigma=\frac{1}{\rho}=q(n\mu_n+p\mu_p).$$
#
# For fully ionized n-type silicon, electrons dominate and $n\approx N_D$, giving $\sigma\approx qN_D\mu_n$. Therefore, a shorter or wider bar has less resistance, while a larger donor concentration usually increases conductivity. Ohm's law then gives $I=V/R$.

# %%
# User-settable geometry and doping
bar_length_um = 1000       # 1 mm
bar_width_um = 100         # cross-section
bar_height_um = 100        # cross-section
doping_levels = [1e15, 1e16, 1e17]  # donor concentration (cm^-3)
bar_voltages = np.linspace(0, 0.1, 6)

# DEVSIM uses centimetres
bar_length_cm, bar_width_cm, bar_height_cm = 1e-4 * np.array(
    [bar_length_um, bar_width_um, bar_height_um]
)

# %%
# Drag to rotate the bar and scroll to zoom
pv_cell.display_silicon_bar(
    length=bar_length_um,
    width=bar_width_um,
    height=bar_height_um,
)

# %%
bar_iv = pv_cell.simulate_doped_silicon_bar(
    doping_levels, bar_voltages,
    length=bar_length_cm, width=bar_width_cm, height=bar_height_cm,
)

for doping, current in bar_iv.items():
    plt.plot(bar_voltages, np.abs(current), 'o-', label=f'{doping:.0e} cm$^{{-3}}$')

plt.xlabel('Voltage across bar (V)')
plt.ylabel('Current (A)')
plt.title('More doping makes silicon more conductive')
plt.grid(True)
plt.legend(title='Donor doping')
plt.show()

# %% [markdown]
# #### Student task: design a 15 Ω silicon bar
#
# Choose the dimensions and donor concentration, run the DEVSIM model, and use the slope of the I–V curve to obtain a resistance as close as possible to 15 Ω. More than one design can work.

# %%
target_resistance = 15  # ohms

# 1. Choose dimensions in µm and a donor concentration in cm^-3.
# trial_length_um = ...
# trial_width_um = ...
# trial_height_um = ...
# trial_doping = ...

# 2. Convert the dimensions from µm to cm.
# trial_length_cm = trial_length_um * 1e-4
# trial_width_cm = trial_width_um * 1e-4
# trial_height_cm = trial_height_um * 1e-4

# 3. Simulate two or more voltages.
# trial_v = np.linspace(0, 0.1, 6)
# trial_iv = pv_cell.simulate_doped_silicon_bar(
#     [trial_doping], trial_v, length=trial_length_cm,
#     width=trial_width_cm, height=trial_height_cm,
# )[trial_doping]

# 4. Find R from the I-V slope, compare it with 15 Ω, and revise.
# conductance = np.polyfit(trial_v, np.abs(trial_iv), 1)[0]
# resistance = 1 / conductance
# print(f'Resistance = {resistance:.2f} Ω')

# %%
# Clear the silicon-bar simulations before creating the solar cell
for device_name in list(devsim.get_device_list()):
    devsim.delete_device(device=device_name)

for mesh_name in list(devsim.get_mesh_list()):
    devsim.delete_mesh(mesh=mesh_name)

print('DEVSIM devices and meshes cleared.')

# %% [markdown]
# ### 2. AM1.5G Photon Absorption Limit
#
# The ASTM G173-03 AM1.5G spectrum gives the incident spectral irradiance $I_\lambda$ in W m$^{-2}$ nm$^{-1}$. A photon of wavelength $\lambda$ has energy
#
# $$E_{ph}=\frac{hc}{\lambda},$$
#
# so the spectral photon flux is $\phi_\lambda=I_\lambda/E_{ph}$. An ideal semiconductor absorbs every photon with $E_{ph}\geq E_g$, equivalently $\lambda\leq\lambda_g=hc/E_g$. The number of absorbable photons and the maximum obtainable current density are therefore
#
# $$\dot N_{abs}=\int_{E_g}^{\infty}\phi_E(E)\,dE=\int_0^{\lambda_g}\phi_\lambda(\lambda)\,d\lambda,$$
#
# $$J_{max}=q\dot N_{abs}.$$
#
# This upper limit assumes that every absorbed photon creates exactly one collected electron–hole pair, with no reflection, transmission, or recombination losses.

# %%
bandgap_wavelength_nm = 1100  # set the material absorption edge
solar_limit = pv_cell.am15g_absorption_limit(bandgap_wavelength_nm)

print(f"Bandgap energy: {solar_limit['bandgap_eV']:.2f} eV")
print(f"Absorbable photon flux: {solar_limit['photon_flux_m2_s']:.3e} m^-2 s^-1")
print(f"Maximum current density: {solar_limit['maximum_current_density_mA_cm2']:.2f} mA/cm^2")

# %% [markdown]
# #### Student exercise: current from a 1.5 eV absorber
#
# A hypothetical semiconductor has a bandgap of 1.5 eV. Convert this energy to its absorption-edge wavelength using $\lambda_g(\mathrm{nm})=1239.84/E_g(\mathrm{eV})$, then use the AM1.5G function to find its maximum current density.

# %%
exercise_bandgap_eV = 1.5

# Complete these two lines:
# exercise_wavelength_nm = ...
# exercise_current = pv_cell.am15g_absorption_limit(exercise_wavelength_nm)
# print(exercise_current['maximum_current_density_mA_cm2'], 'mA/cm^2')

# %% [markdown]
# ### 3. Photovoltage and Quasi-Fermi-Level Splitting
#
# #### Why a solar cell can produce voltage
#
# Voltage measures the energy available to do electrical work per unit charge. In the dark and at equilibrium, electrons and holes share one Fermi level: there is no separation of their electrochemical potentials and therefore no photovoltage. Absorbed light creates excess electron–hole pairs. If those carriers persist, the electron and hole populations can no longer be described by one equilibrium Fermi level. They are instead described by an electron quasi-Fermi level $E_{Fn}$ and a hole quasi-Fermi level $E_{Fp}$. Their separation is the free energy per collected electron–hole pair.
#
# #### Doping and equilibrium carrier concentrations
#
# Assuming complete dopant ionization and non-degenerate statistics, charge neutrality gives approximately
#
# $$n_0\approx N_D \quad \text{for n-type material}, \qquad p_0\approx N_A \quad \text{for p-type material}.$$
#
# The minority-carrier concentration follows from the mass-action law,
#
# $$n_0p_0=n_i^2,$$
#
# where the intrinsic carrier concentration is approximated by
#
# $$n_i=\sqrt{N_CN_V}\exp\left(-\frac{E_g}{2kT}\right).$$
#
# Under the Boltzmann approximation, carrier concentration and Fermi energy are related by
#
# $$E_F-E_i=kT\ln\left(\frac{n}{n_i}\right), \qquad E_i-E_F=kT\ln\left(\frac{p}{n_i}\right).$$
#
# #### Excess carriers and quasi-Fermi levels
#
# Illumination adds electron–hole pairs in equal numbers, $\Delta n=\Delta p$. The total concentrations become
#
# $$n=n_0+\Delta n, \qquad p=p_0+\Delta p.$$
#
# The separate carrier populations then define
#
# $$E_{Fn}=E_i+kT\ln\left(\frac{n}{n_i}\right), \qquad E_{Fp}=E_i-kT\ln\left(\frac{p}{n_i}\right),$$
#
# and hence
#
# $$\Delta E_F=E_{Fn}-E_{Fp}=kT\ln\left(\frac{np}{n_i^2}\right), \qquad V_{oc}\leq\frac{\Delta E_F}{q}.$$
#
# The equality is an optimistic material limit. Contact losses, recombination, transport losses, and imperfect absorption reduce the terminal voltage of a real device.
#
# To connect the earlier photon calculation to an illustrative excess-carrier density, we assume uniform absorption in a layer of thickness $d$ and a carrier lifetime $\tau$. In steady state,
#
# $$G\approx\frac{\dot N_{abs}}{d}, \qquad \Delta n=\Delta p\approx G\tau.$$
#
# This is a simplified estimate: current density alone does not uniquely determine carrier concentration or voltage without assumptions about thickness, lifetime, absorption, and recombination.

# %%
# Illustrative silicon estimate using the photon flux calculated above
absorber_thickness_cm = 100e-4  # 100 µm
carrier_lifetime_s = 1e-3
donor_doping_cm3 = 1e16

photon_flux_cm2_s = solar_limit['photon_flux_m2_s'] / 1e4
generation_cm3_s = photon_flux_cm2_s / absorber_thickness_cm
excess_carriers_cm3 = generation_cm3_s * carrier_lifetime_s

silicon_voltage = pv_cell.quasi_fermi_voltage(
    bandgap_eV=solar_limit['bandgap_eV'],
    doping_cm3=donor_doping_cm3,
    excess_carriers_cm3=excess_carriers_cm3,
)

print(f"Excess carrier density: {excess_carriers_cm3:.3e} cm^-3")
print(f"Maximum material voltage: {silicon_voltage['maximum_voltage_V']:.3f} V")

# %% [markdown]
# #### Student exercise: current and voltage for a 1.5 eV solar cell
#
# Using the same 100 µm thickness, 1 ms lifetime, and $10^{16}$ cm$^{-3}$ donor concentration, calculate both the ideal current density and the quasi-Fermi-level voltage for a 1.5 eV material. Which assumptions make these values upper estimates?

# %%
# bandgap_15_eV = 1.5
# cutoff_15_nm = ...
# solar_limit_15 = pv_cell.am15g_absorption_limit(cutoff_15_nm, plot=False)
# excess_15_cm3 = ...
# voltage_15 = pv_cell.quasi_fermi_voltage(
#     bandgap_15_eV, donor_doping_cm3, excess_15_cm3, plot=False
# )
# print('Current density:', ..., 'mA/cm^2')
# print('Maximum voltage:', ..., 'V')

# %% [markdown]
# #### Maximum power output
#
# A solar cell cannot normally deliver its short-circuit current and open-circuit voltage at the same operating point. The rectangular product $J_{SC}V_{OC}$ is therefore an upper bound, while the maximum-power point is
#
# $$P_{MPP}=J_{MPP}V_{MPP}=FF\,J_{SC}V_{OC},$$
#
# where $FF$ is the fill factor. For an ideal single-diode cell, a useful approximation is
#
# $$FF\approx\frac{v_{oc}-\ln(v_{oc}+0.72)}{v_{oc}+1}, \qquad v_{oc}=\frac{qV_{OC}}{kT}.$$
#
# The following worked estimate applies these relationships to the hypothetical 1.5 eV cell. It remains optimistic because it uses perfect photon collection and the quasi-Fermi splitting as $V_{OC}$.

# %%
bandgap_15_eV = 1.5
cutoff_15_nm = 1239.841984 / bandgap_15_eV
solar_limit_15 = pv_cell.am15g_absorption_limit(cutoff_15_nm, plot=False)
excess_15_cm3 = (solar_limit_15['photon_flux_m2_s'] / 1e4
                   / absorber_thickness_cm * carrier_lifetime_s)
voltage_15 = pv_cell.quasi_fermi_voltage(
    bandgap_15_eV, donor_doping_cm3, excess_15_cm3, plot=False
)['maximum_voltage_V']
current_15 = solar_limit_15['maximum_current_density_mA_cm2']
normalized_voc = voltage_15 / (8.617333262e-5 * 300)
ideal_fill_factor = (normalized_voc - np.log(normalized_voc + 0.72)) / (normalized_voc + 1)
maximum_power_15 = ideal_fill_factor * current_15 * voltage_15

print(f"Ideal current density: {current_15:.2f} mA/cm^2")
print(f"Estimated maximum voltage: {voltage_15:.3f} V")
print(f"Ideal-diode fill factor: {ideal_fill_factor:.3f}")
print(f"Estimated maximum power density: {maximum_power_15:.2f} mW/cm^2")

# %% [markdown]
# ### 4. Creating a complex PN junction the Device
#
# We need to initialize the simulation by defining the device and region names. The code below first removes any existing device or mesh with the same name to ensure a clean start.
#
# The function `create_mesh()` generates the **computational mesh**, which divides the semiconductor into many small segments. Instead of solving the semiconductor equations everywhere at once, DEVSIM solves them at each point in the mesh and connects the solutions together. A finer mesh generally improves accuracy but requires more computation.
#
# The function `set_parameters()` assigns the **material properties** of silicon needed for the simulation. These include quantities such as the permittivity, intrinsic carrier concentration, electron and hole mobilities, and temperature-dependent constants. These properties determine how electric fields form and how charge carriers move through the semiconductor.

# %%
device = "SiliconSolarCell"
region = "Silicon"

# Safe cleanup
if device in devsim.get_device_list():
  devsim.delete_device(device=device)

if "dio" in devsim.get_mesh_list():
    devsim.delete_mesh(mesh="dio")

pv_cell.create_mesh(
    device=device,
    region=region,
)

pv_cell.set_parameters(
    device=device,
    region=region,
)
# Out:
# mid
# bot
#  (region: Silicon)
#  (contact: top)
#  (contact: bot)

# %% [markdown]
# ### 5. Visualizing the Computational Mesh
#
# Below we plot  the **computational mesh** used to represent the one-dimensional silicon diode. Each blue marker corresponds to a **mesh node**, where DEVSIM calculates quantities such as the electrostatic potential, electron concentration, and hole concentration.
#
# The nodes are connected internally by the simulator to form small computational elements over which the semiconductor equations are solved. Notice that the nodes are **more closely spaced near the p–n junction**, where the electric field and carrier concentrations change rapidly. Using a finer mesh in these regions improves the accuracy of the simulation while keeping the overall computation efficient.
#
# **Plotting with Matplotlib**
#
# The `plt` library from **Matplotlib**  is widely used for creating scientific figures. In this notebook, we use it to visualize the computational mesh and later to plot quantities such as carrier concentrations, electric potential, and the diode current–voltage (I–V) characteristics.
#
# For more examples and the full documentation, visit:
# https://matplotlib.org/stable/users/index.html

# %%
# Extract the x-coordinates of the mesh nodes
x = np.array(get_node_model_values(
    device=device,
    region=region,
    name="x"
))

# Plot the computational mesh
plt.figure(figsize=(8, 1.8))
plt.scatter(
    x,
    np.zeros_like(x),
    s=20,
    facecolors="white",
    edgecolors="tab:blue",
    linewidths=1.5
)
plt.yticks([])
plt.xlabel("Position (cm)")
plt.title("One-Dimensional Computational Mesh")
plt.grid(axis="x", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Defining the Physical Properties of the Diode
#
# We next complete the physical description of the silicon diode by specifying two important quantities: the **carrier lifetimes** (`taun` and `taup`) and the **doping profile**.
#
# The carrier lifetimes determine how long **electrons** (`taun`) and **holes** (`taup`) exist before they recombine. These parameters influence how efficiently charge carriers can travel through the device and therefore affect the diode current.
#
# We then define the **net doping profile**, which specifies the spatial distribution of donor and acceptor atoms. This creates the p-type and n-type regions that form the p–n junction and generate the built-in electric field responsible for diode operation.
#
# Finally, we extract the doping profile from the simulation and plot it as a function of position. This allows us to verify that the p–n junction has been defined correctly before solving the semiconductor transport equations.

# %%
set_parameter(
    device=device,
    region=region,
    name="taun",
    value=1e-3,
)

set_parameter(
    device=device,
    region=region,
    name="taup",
    value=1e-3,
)
pv_cell.set_net_doping(
    device=device,
    region=region,
)
x_cm = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="x",
    )
)

net_doping = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="NetDoping",
    )
)

x_um = x_cm * 1e4

plt.figure(figsize=(5, 3))
plt.plot(x_um, net_doping)
plt.axhline(0, linewidth=0.8)
plt.xlabel("Position (µm)")
plt.ylabel("Net doping (cm$^{-3}$)")
plt.title("Silicon pn-junction doping profile")
plt.grid(True)
plt.show()

# the left side of 50 nm is doped with acceptor atoms, and the right hand side with donor atoms
# Out:
# Replacing Node Model Acceptors in region Silicon of material Si
# Replacing Node Model Donors in region Silicon of material Si
# Replacing Node Model NetDoping in region Silicon of material Si

# %% [markdown]
# ### 7. Solving Poisson’s Equation at Equilibrium
#
# We now compute the **electrostatic equilibrium** of the diode by solving **Poisson’s equation**. This is the first major physics solution in the notebook, and it gives us the built-in potential and depletion region that form naturally at the p–n junction before any external bias is applied.
#
# For a semiconductor, Poisson’s equation is
#
# $$
# \nabla \cdot (\epsilon \nabla \phi) = -\rho
# $$
#
# where:
#
# - $\phi$ is the **electrostatic potential**,
# - $\epsilon$ is the **permittivity** of silicon,
# - $\rho$ is the **net charge density** inside the device.
#
# The charge density is calculated from the mobile carriers and the ionized dopants:
#
# $$
# \rho = q\,(p - n + N_D^+ - N_A^-)
# $$
#
# where:
#
# - $q$ is the elementary charge,
# - $n$ is the **electron concentration**,
# - $p$ is the **hole concentration**,
# - $N_D^+$ is the concentration of **ionized donor atoms**,
# - $N_A^-$ is the concentration of **ionized acceptor atoms**.
#
# This means that electrons and acceptors contribute **negative charge**, while holes and donors contribute **positive charge**. In a p–n junction, the spatial imbalance between these charges is what creates the built-in electric field.
#
# The call to `initial_solution()` sets up the potential-only problem and applies the contact boundary conditions, while `solve()` finds the equilibrium solution using a Newton-type iterative method. The solver settings control convergence:
#
# - `absolute_error` sets the allowed absolute residual,
# - `relative_error` sets the allowed residual relative to the problem size,
# - `maximum_iterations` limits the number of Newton steps.
#
# This equilibrium solution becomes the starting point for the full drift–diffusion simulation that follows.

# %%
pv_cell.initial_solution(
    device=device,
    region=region,
)

solve(
    type="dc",
    absolute_error=1.0,
    relative_error=1e-10,
    maximum_iterations=50,
)
# Out:
# number of equations 465
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.00000e+00	AbsError: 8.88882e-02
#     Region: "Silicon"	RelError: 1.00000e+00	AbsError: 8.88882e-02
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 8.88882e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 4.91285e-01	AbsError: 8.58427e-02
#     Region: "Silicon"	RelError: 4.91285e-01	AbsError: 8.58427e-02
#       Equation: "PotentialEquation"	RelError: 4.91285e-01	AbsError: 8.58427e-02
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.20761e-01	AbsError: 8.25143e-02
#     Region: "Silicon"	RelError: 3.20761e-01	AbsError: 8.25143e-02
#       Equation: "PotentialEquation"	RelError: 3.20761e-01	AbsError: 8.25143e-02
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.34478e-01	AbsError: 7.87938e-02
#     Region: "Silicon"	RelError: 2.34478e-01	AbsError: 7.87938e-02
#       Equation: "PotentialEquation"	RelError: 2.34478e-01	AbsError: 7.87938e-02
# Iteration: 4
#   Device: "SiliconSolarCell"	RelError: 1.94308e-01	AbsError: 7.35513e-02
#     Region: "Silicon"	RelError: 1.94308e-01	AbsError: 7.35513e-02
#       Equation: "PotentialEquation"	RelError: 1.94308e-01	AbsError: 7.35513e-02
# Iteration: 5
#   Device: "SiliconSolarCell"	RelError: 2.20512e+00	AbsError: 5.56633e-02
#     Region: "Silicon"	RelError: 2.20512e+00	AbsError: 5.56633e-02
#       Equation: "PotentialEquation"	RelError: 2.20512e+00	AbsError: 5.56633e-02
# Iteration: 6
#   Device: "SiliconSolarCell"	RelError: 4.42954e-01	AbsError: 3.95692e-02
#     Region: "Silicon"	RelError: 4.42954e-01	AbsError: 3.95692e-02
#       Equation: "PotentialEquation"	RelError: 4.42954e-01	AbsError: 3.95692e-02
# Iteration: 7
#   Device: "SiliconSolarCell"	RelError: 6.44444e-02	AbsError: 2.91367e-02
#     Region: "Silicon"	RelError: 6.44444e-02	AbsError: 2.91367e-02
#       Equation: "PotentialEquation"	RelError: 6.44444e-02	AbsError: 2.91367e-02
# Iteration: 8
#   Device: "SiliconSolarCell"	RelError: 5.18778e-02	AbsError: 2.47384e-02
#     Region: "Silicon"	RelError: 5.18778e-02	AbsError: 2.47384e-02
#       Equation: "PotentialEquation"	RelError: 5.18778e-02	AbsError: 2.47384e-02
# Iteration: 9
#   Device: "SiliconSolarCell"	RelError: 8.86327e-04	AbsError: 4.22634e-04
#     Region: "Silicon"	RelError: 8.86327e-04	AbsError: 4.22634e-04
#       Equation: "PotentialEquation"	RelError: 8.86327e-04	AbsError: 4.22634e-04
# Iteration: 10
#   Device: "SiliconSolarCell"	RelError: 4.57979e-06	AbsError: 9.93520e-07
#     Region: "Silicon"	RelError: 4.57979e-06	AbsError: 9.93520e-07
#       Equation: "PotentialEquation"	RelError: 4.57979e-06	AbsError: 9.93520e-07
# Iteration: 11
#   Device: "SiliconSolarCell"	RelError: 9.66443e-11	AbsError: 7.81762e-12
#     Region: "Silicon"	RelError: 9.66443e-11	AbsError: 7.81762e-12
#       Equation: "PotentialEquation"	RelError: 9.66443e-11	AbsError: 7.81762e-12

# %% [markdown]
# ### 8. Solving the Drift–Diffusion Equations
#
# With the electrostatic potential now known, we can move on to the **full semiconductor device simulation** by introducing the transport of charge carriers.
#
# The function `drift_diffusion_initial_solution()` creates two additional solution variables:
#
# - the **electron concentration**, $n$,
# - the **hole concentration**, $p$.
#
# These variables are given physically reasonable initial values based on the equilibrium solution and the transport equations are assembled. The simulator now solves **three coupled equations** simultaneously:
#
# 1. **Poisson's equation**
#
# $$
# \nabla \cdot (\epsilon \nabla \phi) = -q\left(p - n + N_D^+ - N_A^-\right),
# $$
#
# which determines the electrostatic potential $\phi$.
#
# 2. **Electron continuity equation**
#
# $$
# \nabla \cdot \mathbf{J}_n = q(G - R),
# $$
#
# which describes the conservation of electrons.
#
# 3. **Hole continuity equation**
#
# $$
# -\nabla \cdot \mathbf{J}_p = q(G - R),
# $$
#
# which describes the conservation of holes.
#
# The electron and hole current densities are themselves composed of **drift** and **diffusion** components:
#
# $$
# \mathbf{J}_n = q\mu_n n\mathbf{E} + qD_n\nabla n,
# $$
#
# $$
# \mathbf{J}_p = q\mu_p p\mathbf{E} - qD_p\nabla p,
# $$
#
# where:
#
# - $\mu_n$ and $\mu_p$ are the electron and hole mobilities,
# - $D_n$ and $D_p$ are the diffusion coefficients,
# - $\mathbf{E}$ is the electric field,
# - $\nabla n$ and $\nabla p$ are the carrier concentration gradients.
#
# The **drift** terms describe carrier motion caused by the electric field, while the **diffusion** terms describe carrier motion from regions of high concentration to regions of low concentration.
#
# The `solve()` command now finds a **self-consistent solution** for all three equations simultaneously. Because the carrier concentrations and electric potential all depend on one another, DEVSIM repeatedly updates each variable until the entire system converges. This coupled drift–diffusion solution forms the basis for predicting the electrical behaviour of the diode under applied bias.

# %%
pv_cell.drift_diffusion_initial_solution(
    device=device,
    region=region,
)

solve(
    type="dc",
    absolute_error=1e10,
    relative_error=1e-10,
    maximum_iterations=50,
)
# Out:
# Warning: Replacing equation with equation of the same name.
# Region: Silicon, Equation: PotentialEquation, Variable: Potential
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.13338e-13	AbsError: 1.02400e+04
#     Region: "Silicon"	RelError: 2.13338e-13	AbsError: 1.02400e+04
#       Equation: "ElectronContinuityEquation"	RelError: 7.91630e-15	AbsError: 5.12000e+03
#       Equation: "HoleContinuityEquation"	RelError: 7.78299e-15	AbsError: 5.12000e+03
#       Equation: "PotentialEquation"	RelError: 1.97639e-13	AbsError: 1.20768e-16

# %% [markdown]
# ### 9. Equilibrium Solution Profiles
#
# We now view the main equilibrium quantities of the diode together. The top panel shows the electrostatic potential $ \phi $, which is set by the charge balance inside the device. The middle panel shows the electron and hole concentrations, $n$ and $p$, which reflect how the carriers redistribute across the p–n junction at equilibrium. The bottom panel shows the electric field $E$, which is strongest near the depletion region where the carrier concentrations change most rapidly.
#
# These three plots are closely connected: the doping profile creates charge imbalance, the charge imbalance sets the potential, and the potential produces the electric field that controls carrier motion.

# %%
potential = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="Potential",
    )
)

electrons = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="Electrons",
    )
)

holes = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="Holes",
    )
)

electric_field = np.asarray(
    get_edge_model_values(
        device=device,
        region=region,
        name="ElectricField",
    )
)

x_edge_um = 0.5 * (x_um[:-1] + x_um[1:])

fig, axes = plt.subplots(3, 1, figsize=(6, 6), sharex=True)

axes[0].plot(x_um, potential)
axes[0].set_ylabel("Potential (V)")
axes[0].set_title("Equilibrium electrostatic potential")
axes[0].grid(True)

axes[1].semilogy(x_um, electrons, label="Electrons")
axes[1].semilogy(x_um, holes, label="Holes")
axes[1].set_ylabel("Carrier density (cm$^{-3}$)")
axes[1].set_title("Equilibrium carrier concentrations")
axes[1].legend()
axes[1].grid(True)

axes[2].plot(x_edge_um, electric_field)
axes[2].set_xlabel("Position (µm)")
axes[2].set_ylabel("Electric field (V/cm)")
axes[2].set_title("Electric field through the junction")
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. Equilibrium Energy Band Diagram
#
# We now plot the semiconductor energy bands across the diode. The conduction band edge $E_c$ and valence band edge $E_v$ bend with the electrostatic potential, while the Fermi level $E_F$ remains flat at equilibrium.
#
# This plot helps us see how the built-in electric field and the doping profile shape the band structure of the p–n junction before any external bias is applied.

# %%
# Equilibrium energy band diagram

from devsim import get_parameter

Eg = 1.12  # approximate silicon band gap in eV
Vt = 0.02585  # thermal voltage at room temperature in eV

potential = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="Potential",
    )
)

electrons = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="Electrons",
    )
)

intrinsic_electrons = np.asarray(
    get_node_model_values(
        device=device,
        region=region,
        name="IntrinsicElectrons",
    )
)

# Prevent numerical issues
eps = 1e-30
electrons = np.clip(electrons, eps, None)
intrinsic_electrons = np.clip(intrinsic_electrons, eps, None)


# ------------------------------------------------------------------
# Electron quasi-Fermi potential
# (constant everywhere at equilibrium)
# ------------------------------------------------------------------

phi_n = Vt * np.log(electrons / intrinsic_electrons)

# Choose the energy reference so that
# EF = 0 eV at the right contact (x = end)

Ef0 = phi_n[-1]
Ef = -phi_n - Ef0


# ------------------------------------------------------------------
# Band edges
#
# Their absolute energy is arbitrary, so we use the same reference
# shift applied to the Fermi level.
# ------------------------------------------------------------------

Ei = -potential - Ef0
Ec = Ei + Eg / 2
Ev = Ei - Eg / 2


plt.figure(figsize=(8, 4.5))

plt.plot(x_um, Ec, label=r"$E_c$")
plt.plot(x_um, Ei, label=r"$E_i$")
plt.plot(x_um, Ev, label=r"$E_v$")
plt.plot(x_um, phi_n, "k--", linewidth=2, label=r"$E_F$")

plt.xlabel("Position (µm)")
plt.ylabel("Energy (eV)")
plt.title("Equilibrium Energy Band Diagram")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. Calculating the Terminal Current Density
#
# With the equilibrium solution complete, we can now calculate the **terminal current density** at each contact of the diode. The total current flowing through the device is the sum of two contributions:
#
# - the **electron current**, obtained from the electron continuity equation,
# - the **hole current**, obtained from the hole continuity equation.
#
# The function `terminal_current_density()` is created to retrieve these two current components from DEVSIM and adds them together to obtain the **total conventional current density**, measured in A/cm$^2$.
#
# Finally, we evaluate the current density at both the top and bottom contacts. At equilibrium, these values should be essentially zero because there is no external voltage applied and no net flow of charge through the device. Any small non-zero value is simply due to the finite numerical accuracy of the solver.

# %%
# --- helper to read terminal current density ---
def terminal_current_density(contact):
    jn = get_contact_current(
        device=device,
        contact=contact,
        equation="ElectronContinuityEquation",
    )
    jp = get_contact_current(
        device=device,
        contact=contact,
        equation="HoleContinuityEquation",
    )
    return jn + jp

j_top = terminal_current_density("top")
j_bottom = terminal_current_density("bot")

print("Top-contact current density:", j_top, "A/cm^2")
print("Bottom-contact current density:", j_bottom, "A/cm^2")
# Out:
# Top-contact current density: -2.1558854434500012e-09 A/cm^2
# Bottom-contact current density: -4.7046820549940125e-08 A/cm^2

# %% [markdown]
# ### 12. Generating the Dark Current–Voltage (J–V) Characteristic
#
# Having established the equilibrium solution, we now investigate how the diode responds when an **external voltage** is applied across its terminals. This is known as a **DC bias sweep**, and it is one of the most common analyses performed in semiconductor device simulation.
#
# We first identify the voltage parameters associated with the two electrical contacts. The bottom contact is fixed at **0 V**, making it the reference terminal (ground), while the voltage applied to the top contact is varied from **−0.2 V** to **+0.8 V**.
#
# For each applied voltage, DEVSIM solves the complete coupled system of semiconductor equations:
#
# - Poisson's equation, which determines the electrostatic potential,
# - the electron continuity equation,
# - and the hole continuity equation.
#
# Unlike the equilibrium calculation, these equations are now solved under an externally applied bias. The electric potential, carrier concentrations, and current densities all change in response to the applied voltage, so the simulator must find a new self-consistent solution for every voltage in the sweep.
#
# Physically, the applied voltage modifies the height of the built-in potential barrier at the p–n junction:
#
# - Under **forward bias** (positive voltage), the potential barrier is reduced, allowing electrons and holes to diffuse more easily across the junction. As a result, the current increases exponentially.
# - Under **reverse bias** (negative voltage), the potential barrier becomes larger, preventing the majority carriers from crossing the junction. Only a very small reverse saturation current remains.
#
# After each solution converges, we calculate the total current density flowing through the top contact by summing the electron and hole current contributions. These values are stored in the array `dark_current`.
#
# Finally, we plot the current density as a function of the applied voltage to produce the **dark J–V characteristic** of the diode. This curve is called the *dark* characteristic because no optical generation of carriers is included in the simulation. It therefore represents the intrinsic electrical behaviour of the p–n junction and forms the foundation for understanding the operation of solar cells, LEDs, and many other semiconductor devices.

# %%
top_bias_name = simple_physics.GetContactBiasName("top")
bottom_bias_name = simple_physics.GetContactBiasName("bot")

devsim.set_parameter(name="debug_level", value="info")

set_parameter(
    device=device,
    name=bottom_bias_name,
    value=0.0,
)
voltages = np.arange(-0.2, 0.71, 0.02)

dark_current = []

for voltage in voltages:
    set_parameter(
        device=device,
        name=top_bias_name,
        value=float(voltage),
    )

    solve(
        type="dc",
        absolute_error=1e10,
        relative_error=1e-8,
        maximum_iterations=50,
        info=False,
    )

    current = terminal_current_density( "top")
    dark_current.append(current)

dark_current = np.asarray(dark_current)

plt.figure(figsize=(8, 5))
plt.plot(voltages, dark_current,'-o', markersize=4, label="Simulated dark JV")

plt.xlabel("Applied voltage (V)")
plt.ylabel("Dark current density (A/cm$^2$)")
plt.title("Simulated dark JV characteristic")
plt.grid(True)
plt.show()
# Out:
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.59397e+03	AbsError: 4.16597e+17
#     Region: "Silicon"	RelError: 2.59397e+03	AbsError: 4.16597e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.08220e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.52035e+03	AbsError: 2.08377e+17
#       Equation: "PotentialEquation"	RelError: 7.46177e+01	AbsError: 5.60955e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.21951e+02	AbsError: 1.05778e+17
#     Region: "Silicon"	RelError: 1.21951e+02	AbsError: 1.05778e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.98846e-01	AbsError: 5.41296e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.98813e-01	AbsError: 5.16487e+16
#       Equation: "PotentialEquation"	RelError: 1.19954e+02	AbsError: 4.87025e-02
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.03024e+03	AbsError: 2.40408e+16
#     Region: "Silicon"	RelError: 2.03024e+03	AbsError: 2.40408e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.37194e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.03215e+16
#       Equation: "PotentialEquation"	RelError: 3.22362e+01	AbsError: 3.99479e-02
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.14323e+00	AbsError: 1.62897e+15
#     Region: "Silicon"	RelError: 2.14323e+00	AbsError: 1.62897e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.98543e-01	AbsError: 1.84862e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.97629e-01	AbsError: 1.44411e+15
#       Equation: "PotentialEquation"	RelError: 1.47059e-01	AbsError: 2.95806e-02
# Iteration: 4
#   Device: "SiliconSolarCell"	RelError: 9.88825e+00	AbsError: 1.67902e+14
#     Region: "Silicon"	RelError: 9.88825e+00	AbsError: 1.67902e+14
#       Equation: "ElectronContinuityEquation"	RelError: 7.46097e+00	AbsError: 4.67914e+12
#       Equation: "HoleContinuityEquation"	RelError: 2.38936e+00	AbsError: 1.63223e+14
#       Equation: "PotentialEquation"	RelError: 3.79304e-02	AbsError: 2.56735e-02
# Iteration: 5
#   Device: "SiliconSolarCell"	RelError: 7.47355e-01	AbsError: 2.32592e+13
#     Region: "Silicon"	RelError: 7.47355e-01	AbsError: 2.32592e+13
#       Equation: "ElectronContinuityEquation"	RelError: 6.73261e-01	AbsError: 6.64441e+11
#       Equation: "HoleContinuityEquation"	RelError: 7.36704e-02	AbsError: 2.25948e+13
#       Equation: "PotentialEquation"	RelError: 4.23558e-04	AbsError: 4.76400e-07
# Iteration: 6
#   Device: "SiliconSolarCell"	RelError: 3.39282e-06	AbsError: 1.63396e+07
#     Region: "Silicon"	RelError: 3.39282e-06	AbsError: 1.63396e+07
#       Equation: "ElectronContinuityEquation"	RelError: 2.68385e-06	AbsError: 4.74898e+05
#       Equation: "HoleContinuityEquation"	RelError: 7.08954e-07	AbsError: 1.58647e+07
#       Equation: "PotentialEquation"	RelError: 1.44243e-11	AbsError: 2.52602e-13
# Iteration: 7
#   Device: "SiliconSolarCell"	RelError: 1.33800e-14	AbsError: 3.68899e+02
#     Region: "Silicon"	RelError: 1.33800e-14	AbsError: 3.68899e+02
#       Equation: "ElectronContinuityEquation"	RelError: 3.86720e-15	AbsError: 1.78109e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.75995e-15	AbsError: 1.90790e+02
#       Equation: "PotentialEquation"	RelError: 7.75280e-15	AbsError: 6.02225e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.66632e+00	AbsError: 3.76780e+16
#     Region: "Silicon"	RelError: 9.66632e+00	AbsError: 3.76780e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.48253e-01	AbsError: 1.88473e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.48254e-01	AbsError: 1.88307e+16
#       Equation: "PotentialEquation"	RelError: 8.96982e+00	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.16676e-01	AbsError: 7.81205e+14
#     Region: "Silicon"	RelError: 2.16676e-01	AbsError: 7.81205e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.06363e-01	AbsError: 3.90326e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.06375e-01	AbsError: 3.90879e+14
#       Equation: "PotentialEquation"	RelError: 3.93853e-03	AbsError: 2.94256e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.97209e-04	AbsError: 7.32494e+10
#     Region: "Silicon"	RelError: 1.97209e-04	AbsError: 7.32494e+10
#       Equation: "ElectronContinuityEquation"	RelError: 9.85737e-05	AbsError: 3.65895e+10
#       Equation: "HoleContinuityEquation"	RelError: 9.85538e-05	AbsError: 3.66599e+10
#       Equation: "PotentialEquation"	RelError: 8.12753e-08	AbsError: 1.14988e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.54146e-12	AbsError: 6.27662e+02
#     Region: "Silicon"	RelError: 2.54146e-12	AbsError: 6.27662e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.26730e-12	AbsError: 3.68189e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.27365e-12	AbsError: 2.59473e+02
#       Equation: "PotentialEquation"	RelError: 5.05534e-16	AbsError: 5.89084e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 8.82878e+01	AbsError: 3.80531e+16
#     Region: "Silicon"	RelError: 8.82878e+01	AbsError: 3.80531e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.52298e-01	AbsError: 1.90235e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.52306e-01	AbsError: 1.90296e+16
#       Equation: "PotentialEquation"	RelError: 8.75832e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.55341e-01	AbsError: 7.96978e+14
#     Region: "Silicon"	RelError: 2.55341e-01	AbsError: 7.96978e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.09835e-01	AbsError: 3.98727e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.09821e-01	AbsError: 3.98251e+14
#       Equation: "PotentialEquation"	RelError: 3.56849e-02	AbsError: 2.98538e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.12637e-04	AbsError: 7.53071e+10
#     Region: "Silicon"	RelError: 2.12637e-04	AbsError: 7.53071e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.05924e-04	AbsError: 3.77339e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.05948e-04	AbsError: 3.75733e+10
#       Equation: "PotentialEquation"	RelError: 7.64615e-07	AbsError: 1.18764e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.87804e-12	AbsError: 4.37732e+02
#     Region: "Silicon"	RelError: 2.87804e-12	AbsError: 4.37732e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.42864e-12	AbsError: 1.75334e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.42860e-12	AbsError: 2.62398e+02
#       Equation: "PotentialEquation"	RelError: 2.08033e-14	AbsError: 5.58668e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 3.96495e+01	AbsError: 3.83838e+16
#     Region: "Silicon"	RelError: 3.96495e+01	AbsError: 3.83838e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.56674e-01	AbsError: 1.92012e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.56659e-01	AbsError: 1.91826e+16
#       Equation: "PotentialEquation"	RelError: 3.89362e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.41275e-01	AbsError: 8.13512e+14
#     Region: "Silicon"	RelError: 2.41275e-01	AbsError: 8.13512e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.13670e-01	AbsError: 4.06620e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.13657e-01	AbsError: 4.06892e+14
#       Equation: "PotentialEquation"	RelError: 1.39476e-02	AbsError: 3.02964e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.28367e-04	AbsError: 7.77214e+10
#     Region: "Silicon"	RelError: 2.28367e-04	AbsError: 7.77214e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.14045e-04	AbsError: 3.87960e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.14011e-04	AbsError: 3.89254e+10
#       Equation: "PotentialEquation"	RelError: 3.10513e-07	AbsError: 1.22619e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.22484e-12	AbsError: 5.02198e+02
#     Region: "Silicon"	RelError: 3.22484e-12	AbsError: 5.02198e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.58858e-12	AbsError: 2.60211e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.58939e-12	AbsError: 2.41988e+02
#       Equation: "PotentialEquation"	RelError: 4.68619e-14	AbsError: 6.36415e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.27037e+01	AbsError: 3.87764e+16
#     Region: "Silicon"	RelError: 4.27037e+01	AbsError: 3.87764e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.61338e-01	AbsError: 1.93849e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.61345e-01	AbsError: 1.93915e+16
#       Equation: "PotentialEquation"	RelError: 4.19810e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.48564e-01	AbsError: 8.29528e+14
#     Region: "Silicon"	RelError: 2.48564e-01	AbsError: 8.29528e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.17906e-01	AbsError: 4.14914e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.17902e-01	AbsError: 4.14614e+14
#       Equation: "PotentialEquation"	RelError: 1.27555e-02	AbsError: 3.07479e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.45710e-04	AbsError: 8.01862e+10
#     Region: "Silicon"	RelError: 2.45710e-04	AbsError: 8.01862e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.22694e-04	AbsError: 4.01525e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.22721e-04	AbsError: 4.00338e+10
#       Equation: "PotentialEquation"	RelError: 2.95262e-07	AbsError: 1.26826e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.50261e-12	AbsError: 4.60130e+02
#     Region: "Silicon"	RelError: 3.50261e-12	AbsError: 4.60130e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.75025e-12	AbsError: 2.30371e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.75000e-12	AbsError: 2.29759e+02
#       Equation: "PotentialEquation"	RelError: 2.35971e-15	AbsError: 5.57539e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.91737e+01	AbsError: 3.91281e+16
#     Region: "Silicon"	RelError: 1.91737e+01	AbsError: 3.91281e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.66365e-01	AbsError: 1.95734e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.66386e-01	AbsError: 1.95548e+16
#       Equation: "PotentialEquation"	RelError: 1.84409e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.50204e-01	AbsError: 8.48047e+14
#     Region: "Silicon"	RelError: 2.50204e-01	AbsError: 8.48047e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.22632e-01	AbsError: 4.24074e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.22626e-01	AbsError: 4.23974e+14
#       Equation: "PotentialEquation"	RelError: 4.94563e-03	AbsError: 3.12211e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.63290e-04	AbsError: 8.26314e+10
#     Region: "Silicon"	RelError: 2.63290e-04	AbsError: 8.26314e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.31587e-04	AbsError: 4.12287e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.31585e-04	AbsError: 4.14027e+10
#       Equation: "PotentialEquation"	RelError: 1.19117e-07	AbsError: 1.31065e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.80949e-12	AbsError: 4.39011e+02
#     Region: "Silicon"	RelError: 3.80949e-12	AbsError: 4.39011e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.90075e-12	AbsError: 1.79980e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.89838e-12	AbsError: 2.59030e+02
#       Equation: "PotentialEquation"	RelError: 1.03544e-14	AbsError: 5.77848e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.31357e+02	AbsError: 3.95447e+16
#     Region: "Silicon"	RelError: 2.31357e+02	AbsError: 3.95447e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.71838e-01	AbsError: 1.97698e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.71859e-01	AbsError: 1.97749e+16
#       Equation: "PotentialEquation"	RelError: 2.30613e+02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.03317e-01	AbsError: 8.65608e+14
#     Region: "Silicon"	RelError: 3.03317e-01	AbsError: 8.65608e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.27918e-01	AbsError: 4.32527e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.27897e-01	AbsError: 4.33081e+14
#       Equation: "PotentialEquation"	RelError: 4.75015e-02	AbsError: 3.17030e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.81235e-04	AbsError: 8.54849e+10
#     Region: "Silicon"	RelError: 2.81235e-04	AbsError: 8.54849e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.40015e-04	AbsError: 4.27886e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.40029e-04	AbsError: 4.26963e+10
#       Equation: "PotentialEquation"	RelError: 1.19134e-06	AbsError: 1.35756e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 4.72278e-12	AbsError: 5.43316e+02
#     Region: "Silicon"	RelError: 4.72278e-12	AbsError: 5.43316e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.32369e-12	AbsError: 2.12110e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.32140e-12	AbsError: 3.31206e+02
#       Equation: "PotentialEquation"	RelError: 7.76915e-14	AbsError: 5.85093e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.00956e+02	AbsError: 3.99195e+16
#     Region: "Silicon"	RelError: 9.00956e+02	AbsError: 3.99195e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.77822e-01	AbsError: 1.99656e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.77829e-01	AbsError: 1.99539e+16
#       Equation: "PotentialEquation"	RelError: 9.00200e+02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 4.44103e-01	AbsError: 8.84659e+14
#     Region: "Silicon"	RelError: 4.44103e-01	AbsError: 8.84659e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.33810e-01	AbsError: 4.42615e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.33828e-01	AbsError: 4.42044e+14
#       Equation: "PotentialEquation"	RelError: 1.76465e-01	AbsError: 3.22075e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.99372e-04	AbsError: 8.80775e+10
#     Region: "Silicon"	RelError: 2.99372e-04	AbsError: 8.80775e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.47393e-04	AbsError: 4.39383e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.47367e-04	AbsError: 4.41392e+10
#       Equation: "PotentialEquation"	RelError: 4.61238e-06	AbsError: 1.40482e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 8.39212e-12	AbsError: 7.20112e+02
#     Region: "Silicon"	RelError: 8.39212e-12	AbsError: 7.20112e+02
#       Equation: "ElectronContinuityEquation"	RelError: 3.39967e-12	AbsError: 3.13149e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.40013e-12	AbsError: 4.06963e+02
#       Equation: "PotentialEquation"	RelError: 1.59232e-12	AbsError: 6.32618e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 6.55023e+01	AbsError: 4.03608e+16
#     Region: "Silicon"	RelError: 6.55023e+01	AbsError: 4.03608e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.84328e-01	AbsError: 2.01796e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.84305e-01	AbsError: 2.01812e+16
#       Equation: "PotentialEquation"	RelError: 6.47337e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.88122e-01	AbsError: 9.05336e+14
#     Region: "Silicon"	RelError: 2.88122e-01	AbsError: 9.05336e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.40328e-01	AbsError: 4.52645e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.40303e-01	AbsError: 4.52691e+14
#       Equation: "PotentialEquation"	RelError: 7.49082e-03	AbsError: 3.27255e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.06871e-04	AbsError: 9.12876e+10
#     Region: "Silicon"	RelError: 3.06871e-04	AbsError: 9.12876e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.53331e-04	AbsError: 4.56862e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.53336e-04	AbsError: 4.56014e+10
#       Equation: "PotentialEquation"	RelError: 2.04200e-07	AbsError: 1.45696e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 9.13916e-12	AbsError: 7.02044e+02
#     Region: "Silicon"	RelError: 9.13916e-12	AbsError: 7.02044e+02
#       Equation: "ElectronContinuityEquation"	RelError: 4.51450e-12	AbsError: 3.20408e+02
#       Equation: "HoleContinuityEquation"	RelError: 4.51690e-12	AbsError: 3.81637e+02
#       Equation: "PotentialEquation"	RelError: 1.07761e-13	AbsError: 6.40690e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 8.67419e+01	AbsError: 4.07609e+16
#     Region: "Silicon"	RelError: 8.67419e+01	AbsError: 4.07609e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.91349e-01	AbsError: 2.03791e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.91355e-01	AbsError: 2.03818e+16
#       Equation: "PotentialEquation"	RelError: 8.59592e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.99434e-01	AbsError: 9.25232e+14
#     Region: "Silicon"	RelError: 2.99434e-01	AbsError: 9.25232e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.47251e-01	AbsError: 4.62310e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.47236e-01	AbsError: 4.62921e+14
#       Equation: "PotentialEquation"	RelError: 4.94652e-03	AbsError: 3.32564e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.16093e-04	AbsError: 9.41578e+10
#     Region: "Silicon"	RelError: 3.16093e-04	AbsError: 9.41578e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.57985e-04	AbsError: 4.69755e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.57968e-04	AbsError: 4.71823e+10
#       Equation: "PotentialEquation"	RelError: 1.40747e-07	AbsError: 1.50967e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.10874e-11	AbsError: 5.92345e+02
#     Region: "Silicon"	RelError: 1.10874e-11	AbsError: 5.92345e+02
#       Equation: "ElectronContinuityEquation"	RelError: 5.51050e-12	AbsError: 3.33644e+02
#       Equation: "HoleContinuityEquation"	RelError: 5.52239e-12	AbsError: 2.58701e+02
#       Equation: "PotentialEquation"	RelError: 5.44766e-14	AbsError: 8.19909e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.35606e+02	AbsError: 4.12263e+16
#     Region: "Silicon"	RelError: 1.35606e+02	AbsError: 4.12263e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.98733e-01	AbsError: 2.06151e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.98749e-01	AbsError: 2.06112e+16
#       Equation: "PotentialEquation"	RelError: 1.34808e+02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.08409e-01	AbsError: 9.47126e+14
#     Region: "Silicon"	RelError: 3.08409e-01	AbsError: 9.47126e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.54168e-01	AbsError: 4.73852e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.54158e-01	AbsError: 4.73274e+14
#       Equation: "PotentialEquation"	RelError: 8.31635e-05	AbsError: 3.38155e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.23480e-04	AbsError: 9.76751e+10
#     Region: "Silicon"	RelError: 3.23480e-04	AbsError: 9.76751e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.61736e-04	AbsError: 4.88875e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.61740e-04	AbsError: 4.87876e+10
#       Equation: "PotentialEquation"	RelError: 3.38778e-09	AbsError: 1.56794e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.26803e-11	AbsError: 7.22648e+02
#     Region: "Silicon"	RelError: 1.26803e-11	AbsError: 7.22648e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.33462e-12	AbsError: 3.59966e+02
#       Equation: "HoleContinuityEquation"	RelError: 6.33577e-12	AbsError: 3.62681e+02
#       Equation: "PotentialEquation"	RelError: 9.95221e-15	AbsError: 3.23747e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.71826e+02	AbsError: 4.16597e+16
#     Region: "Silicon"	RelError: 1.71826e+02	AbsError: 4.16597e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.06148e-01	AbsError: 2.08220e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.06162e-01	AbsError: 2.08377e+16
#       Equation: "PotentialEquation"	RelError: 1.71013e+02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.31564e-01	AbsError: 9.70712e+14
#     Region: "Silicon"	RelError: 3.31564e-01	AbsError: 9.70712e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.60527e-01	AbsError: 4.85383e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.60523e-01	AbsError: 4.85329e+14
#       Equation: "PotentialEquation"	RelError: 1.05143e-02	AbsError: 3.43887e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.30278e-04	AbsError: 1.00965e+11
#     Region: "Silicon"	RelError: 3.30278e-04	AbsError: 1.00965e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.64968e-04	AbsError: 5.03888e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.64983e-04	AbsError: 5.05764e+10
#       Equation: "PotentialEquation"	RelError: 3.27085e-07	AbsError: 1.62742e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.44104e-11	AbsError: 8.46032e+02
#     Region: "Silicon"	RelError: 1.44104e-11	AbsError: 8.46032e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.99238e-12	AbsError: 4.04108e+02
#       Equation: "HoleContinuityEquation"	RelError: 6.99241e-12	AbsError: 4.41924e+02
#       Equation: "PotentialEquation"	RelError: 4.25598e-13	AbsError: 8.59717e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 3.14681e+01	AbsError: 4.21403e+16
#     Region: "Silicon"	RelError: 3.14681e+01	AbsError: 4.21403e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.13045e-01	AbsError: 2.10759e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.13057e-01	AbsError: 2.10644e+16
#       Equation: "PotentialEquation"	RelError: 3.06420e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.35760e-01	AbsError: 9.94174e+14
#     Region: "Silicon"	RelError: 3.35760e-01	AbsError: 9.94174e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.65844e-01	AbsError: 4.96876e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.65848e-01	AbsError: 4.97298e+14
#       Equation: "PotentialEquation"	RelError: 4.06795e-03	AbsError: 3.49796e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.36259e-04	AbsError: 1.04718e+11
#     Region: "Silicon"	RelError: 3.36259e-04	AbsError: 1.04718e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.68062e-04	AbsError: 5.24299e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.68064e-04	AbsError: 5.22881e+10
#       Equation: "PotentialEquation"	RelError: 1.32465e-07	AbsError: 1.69251e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.51266e-11	AbsError: 8.00853e+02
#     Region: "Silicon"	RelError: 1.51266e-11	AbsError: 8.00853e+02
#       Equation: "ElectronContinuityEquation"	RelError: 7.52913e-12	AbsError: 4.51539e+02
#       Equation: "HoleContinuityEquation"	RelError: 7.53368e-12	AbsError: 3.49313e+02
#       Equation: "PotentialEquation"	RelError: 6.37439e-14	AbsError: 4.67491e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.27472e+01	AbsError: 4.26348e+16
#     Region: "Silicon"	RelError: 4.27472e+01	AbsError: 4.26348e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.18906e-01	AbsError: 2.13141e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.18915e-01	AbsError: 2.13207e+16
#       Equation: "PotentialEquation"	RelError: 4.19094e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.48484e-01	AbsError: 1.01876e+15
#     Region: "Silicon"	RelError: 3.48484e-01	AbsError: 1.01876e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.69917e-01	AbsError: 5.09398e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.69908e-01	AbsError: 5.09357e+14
#       Equation: "PotentialEquation"	RelError: 8.65913e-03	AbsError: 3.56004e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.42369e-04	AbsError: 1.08581e+11
#     Region: "Silicon"	RelError: 3.42369e-04	AbsError: 1.08581e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.71057e-04	AbsError: 5.42212e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.71017e-04	AbsError: 5.43602e+10
#       Equation: "PotentialEquation"	RelError: 2.95482e-07	AbsError: 1.76002e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.61420e-11	AbsError: 9.30005e+02
#     Region: "Silicon"	RelError: 1.61420e-11	AbsError: 9.30005e+02
#       Equation: "ElectronContinuityEquation"	RelError: 8.03848e-12	AbsError: 4.44375e+02
#       Equation: "HoleContinuityEquation"	RelError: 8.03568e-12	AbsError: 4.85629e+02
#       Equation: "PotentialEquation"	RelError: 6.78440e-14	AbsError: 5.52202e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 7.20135e+01	AbsError: 4.31175e+16
#     Region: "Silicon"	RelError: 7.20135e+01	AbsError: 4.31175e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.23478e-01	AbsError: 2.15606e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.23470e-01	AbsError: 2.15568e+16
#       Equation: "PotentialEquation"	RelError: 7.11666e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.66185e-01	AbsError: 1.04559e+15
#     Region: "Silicon"	RelError: 3.66185e-01	AbsError: 1.04559e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.72797e-01	AbsError: 5.23009e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.72801e-01	AbsError: 5.22581e+14
#       Equation: "PotentialEquation"	RelError: 2.05871e-02	AbsError: 3.62398e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.48887e-04	AbsError: 1.12470e+11
#     Region: "Silicon"	RelError: 3.48887e-04	AbsError: 1.12470e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.74056e-04	AbsError: 5.63422e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.74094e-04	AbsError: 5.61274e+10
#       Equation: "PotentialEquation"	RelError: 7.37007e-07	AbsError: 1.83270e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.71100e-11	AbsError: 8.06251e+02
#     Region: "Silicon"	RelError: 1.71100e-11	AbsError: 8.06251e+02
#       Equation: "ElectronContinuityEquation"	RelError: 8.53099e-12	AbsError: 4.19221e+02
#       Equation: "HoleContinuityEquation"	RelError: 8.53218e-12	AbsError: 3.87031e+02
#       Equation: "PotentialEquation"	RelError: 4.68214e-14	AbsError: 3.82975e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.15877e+01	AbsError: 4.36621e+16
#     Region: "Silicon"	RelError: 2.15877e+01	AbsError: 4.36621e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.26752e-01	AbsError: 2.18334e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.26755e-01	AbsError: 2.18287e+16
#       Equation: "PotentialEquation"	RelError: 2.07342e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.57220e-01	AbsError: 1.07374e+15
#     Region: "Silicon"	RelError: 3.57220e-01	AbsError: 1.07374e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.74722e-01	AbsError: 5.36896e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.74724e-01	AbsError: 5.36847e+14
#       Equation: "PotentialEquation"	RelError: 7.77450e-03	AbsError: 3.68992e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.54711e-04	AbsError: 1.17068e+11
#     Region: "Silicon"	RelError: 3.54711e-04	AbsError: 1.17068e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.77208e-04	AbsError: 5.85060e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.77211e-04	AbsError: 5.85615e+10
#       Equation: "PotentialEquation"	RelError: 2.92321e-07	AbsError: 1.90971e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.80981e-11	AbsError: 8.76827e+02
#     Region: "Silicon"	RelError: 1.80981e-11	AbsError: 8.76827e+02
#       Equation: "ElectronContinuityEquation"	RelError: 9.03895e-12	AbsError: 4.66754e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.03227e-12	AbsError: 4.10073e+02
#       Equation: "PotentialEquation"	RelError: 2.68682e-14	AbsError: 5.09227e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.23203e+01	AbsError: 4.41949e+16
#     Region: "Silicon"	RelError: 2.23203e+01	AbsError: 4.41949e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.28973e-01	AbsError: 2.20922e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.28973e-01	AbsError: 2.21027e+16
#       Equation: "PotentialEquation"	RelError: 2.14623e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.61629e-01	AbsError: 1.10274e+15
#     Region: "Silicon"	RelError: 3.61629e-01	AbsError: 1.10274e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.75947e-01	AbsError: 5.51227e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.75947e-01	AbsError: 5.51509e+14
#       Equation: "PotentialEquation"	RelError: 9.73512e-03	AbsError: 3.75924e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.61199e-04	AbsError: 1.21277e+11
#     Region: "Silicon"	RelError: 3.61199e-04	AbsError: 1.21277e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.80420e-04	AbsError: 6.06391e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.80394e-04	AbsError: 6.06382e+10
#       Equation: "PotentialEquation"	RelError: 3.84895e-07	AbsError: 1.99090e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.91728e-11	AbsError: 9.65661e+02
#     Region: "Silicon"	RelError: 1.91728e-11	AbsError: 9.65661e+02
#       Equation: "ElectronContinuityEquation"	RelError: 9.57279e-12	AbsError: 4.91596e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.57852e-12	AbsError: 4.74065e+02
#       Equation: "PotentialEquation"	RelError: 2.15157e-14	AbsError: 5.84899e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.12752e+01	AbsError: 4.47427e+16
#     Region: "Silicon"	RelError: 2.12752e+01	AbsError: 4.47427e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.30401e-01	AbsError: 2.23764e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.30402e-01	AbsError: 2.23662e+16
#       Equation: "PotentialEquation"	RelError: 2.04144e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.64693e-01	AbsError: 1.13290e+15
#     Region: "Silicon"	RelError: 3.64693e-01	AbsError: 1.13290e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76703e-01	AbsError: 5.66166e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.76702e-01	AbsError: 5.66732e+14
#       Equation: "PotentialEquation"	RelError: 1.12885e-02	AbsError: 3.83110e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.67905e-04	AbsError: 1.26451e+11
#     Region: "Silicon"	RelError: 3.67905e-04	AbsError: 1.26451e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.83720e-04	AbsError: 6.32597e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.83716e-04	AbsError: 6.31914e+10
#       Equation: "PotentialEquation"	RelError: 4.69869e-07	AbsError: 2.07922e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.03058e-11	AbsError: 8.09490e+02
#     Region: "Silicon"	RelError: 2.03058e-11	AbsError: 8.09490e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.01492e-11	AbsError: 4.05407e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.01546e-11	AbsError: 4.04083e+02
#       Equation: "PotentialEquation"	RelError: 1.93384e-15	AbsError: 3.53162e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.42531e+01	AbsError: 4.53491e+16
#     Region: "Silicon"	RelError: 2.42531e+01	AbsError: 4.53491e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31289e-01	AbsError: 2.26769e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31289e-01	AbsError: 2.26722e+16
#       Equation: "PotentialEquation"	RelError: 2.33905e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.70420e-01	AbsError: 1.16532e+15
#     Region: "Silicon"	RelError: 3.70420e-01	AbsError: 1.16532e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77153e-01	AbsError: 5.82644e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77152e-01	AbsError: 5.82678e+14
#       Equation: "PotentialEquation"	RelError: 1.61158e-02	AbsError: 3.90576e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.75080e-04	AbsError: 1.31372e+11
#     Region: "Silicon"	RelError: 3.75080e-04	AbsError: 1.31372e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.87170e-04	AbsError: 6.55873e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.87203e-04	AbsError: 6.57849e+10
#       Equation: "PotentialEquation"	RelError: 7.07063e-07	AbsError: 2.17236e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.15357e-11	AbsError: 7.84642e+02
#     Region: "Silicon"	RelError: 2.15357e-11	AbsError: 7.84642e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.07667e-11	AbsError: 4.37845e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.07661e-11	AbsError: 3.46797e+02
#       Equation: "PotentialEquation"	RelError: 2.82693e-15	AbsError: 3.16148e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.99037e+01	AbsError: 4.59526e+16
#     Region: "Silicon"	RelError: 1.99037e+01	AbsError: 4.59526e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31828e-01	AbsError: 2.29725e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31828e-01	AbsError: 2.29802e+16
#       Equation: "PotentialEquation"	RelError: 1.90401e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.70305e-01	AbsError: 1.19962e+15
#     Region: "Silicon"	RelError: 3.70305e-01	AbsError: 1.19962e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77417e-01	AbsError: 6.00120e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77416e-01	AbsError: 5.99504e+14
#       Equation: "PotentialEquation"	RelError: 1.54720e-02	AbsError: 3.98326e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.82317e-04	AbsError: 1.36709e+11
#     Region: "Silicon"	RelError: 3.82317e-04	AbsError: 1.36709e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.90796e-04	AbsError: 6.84738e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.90804e-04	AbsError: 6.82351e+10
#       Equation: "PotentialEquation"	RelError: 7.16385e-07	AbsError: 2.27273e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.28901e-11	AbsError: 8.94327e+02
#     Region: "Silicon"	RelError: 2.28901e-11	AbsError: 8.94327e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.14389e-11	AbsError: 3.87399e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.14448e-11	AbsError: 5.06928e+02
#       Equation: "PotentialEquation"	RelError: 6.39383e-15	AbsError: 3.49470e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.87178e+01	AbsError: 4.65680e+16
#     Region: "Silicon"	RelError: 1.87178e+01	AbsError: 4.65680e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32145e-01	AbsError: 2.32815e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32144e-01	AbsError: 2.32866e+16
#       Equation: "PotentialEquation"	RelError: 1.78535e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.71327e-01	AbsError: 1.23648e+15
#     Region: "Silicon"	RelError: 3.71327e-01	AbsError: 1.23648e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77567e-01	AbsError: 6.18475e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77566e-01	AbsError: 6.18007e+14
#       Equation: "PotentialEquation"	RelError: 1.61936e-02	AbsError: 4.06405e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.89880e-04	AbsError: 1.42856e+11
#     Region: "Silicon"	RelError: 3.89880e-04	AbsError: 1.42856e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.94550e-04	AbsError: 7.14245e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.94537e-04	AbsError: 7.14310e+10
#       Equation: "PotentialEquation"	RelError: 7.92234e-07	AbsError: 2.38048e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.43569e-11	AbsError: 1.04589e+03
#     Region: "Silicon"	RelError: 2.43569e-11	AbsError: 1.04589e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.21727e-11	AbsError: 5.23504e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.21718e-11	AbsError: 5.22389e+02
#       Equation: "PotentialEquation"	RelError: 1.24268e-14	AbsError: 3.33292e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.51368e+01	AbsError: 4.72366e+16
#     Region: "Silicon"	RelError: 1.51368e+01	AbsError: 4.72366e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32328e-01	AbsError: 2.36240e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32327e-01	AbsError: 2.36126e+16
#       Equation: "PotentialEquation"	RelError: 1.42722e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.70958e-01	AbsError: 1.27537e+15
#     Region: "Silicon"	RelError: 3.70958e-01	AbsError: 1.27537e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77649e-01	AbsError: 6.37858e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77648e-01	AbsError: 6.37507e+14
#       Equation: "PotentialEquation"	RelError: 1.56608e-02	AbsError: 4.14898e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.97678e-04	AbsError: 1.48655e+11
#     Region: "Silicon"	RelError: 3.97678e-04	AbsError: 1.48655e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.98449e-04	AbsError: 7.41988e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.98418e-04	AbsError: 7.44558e+10
#       Equation: "PotentialEquation"	RelError: 8.10186e-07	AbsError: 2.49544e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.59436e-11	AbsError: 1.04301e+03
#     Region: "Silicon"	RelError: 2.59436e-11	AbsError: 1.04301e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.29622e-11	AbsError: 5.43823e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.29635e-11	AbsError: 4.99191e+02
#       Equation: "PotentialEquation"	RelError: 1.78980e-14	AbsError: 4.98942e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.10708e+01	AbsError: 4.79378e+16
#     Region: "Silicon"	RelError: 2.10708e+01	AbsError: 4.79378e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32430e-01	AbsError: 2.39699e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32429e-01	AbsError: 2.39679e+16
#       Equation: "PotentialEquation"	RelError: 2.02060e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.81037e-01	AbsError: 1.31655e+15
#     Region: "Silicon"	RelError: 3.81037e-01	AbsError: 1.31655e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77689e-01	AbsError: 6.58417e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77689e-01	AbsError: 6.58129e+14
#       Equation: "PotentialEquation"	RelError: 2.56588e-02	AbsError: 4.23743e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.06394e-04	AbsError: 1.55273e+11
#     Region: "Silicon"	RelError: 4.06394e-04	AbsError: 1.55273e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.02509e-04	AbsError: 7.77586e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.02480e-04	AbsError: 7.75145e+10
#       Equation: "PotentialEquation"	RelError: 1.40456e-06	AbsError: 2.61963e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.76867e-11	AbsError: 1.17884e+03
#     Region: "Silicon"	RelError: 2.76867e-11	AbsError: 1.17884e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.38320e-11	AbsError: 4.90496e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.38374e-11	AbsError: 6.88344e+02
#       Equation: "PotentialEquation"	RelError: 1.72533e-14	AbsError: 3.34928e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.75611e+01	AbsError: 4.86530e+16
#     Region: "Silicon"	RelError: 1.75611e+01	AbsError: 4.86530e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32482e-01	AbsError: 2.43234e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32482e-01	AbsError: 2.43296e+16
#       Equation: "PotentialEquation"	RelError: 1.66961e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.79617e-01	AbsError: 1.36030e+15
#     Region: "Silicon"	RelError: 3.79617e-01	AbsError: 1.36030e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77706e-01	AbsError: 6.80291e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77705e-01	AbsError: 6.80012e+14
#       Equation: "PotentialEquation"	RelError: 2.42061e-02	AbsError: 4.32974e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.14909e-04	AbsError: 1.62647e+11
#     Region: "Silicon"	RelError: 4.14909e-04	AbsError: 1.62647e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.06748e-04	AbsError: 8.13349e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.06760e-04	AbsError: 8.13122e+10
#       Equation: "PotentialEquation"	RelError: 1.40166e-06	AbsError: 2.75426e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.95926e-11	AbsError: 1.31068e+03
#     Region: "Silicon"	RelError: 2.95926e-11	AbsError: 1.31068e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.47860e-11	AbsError: 7.50635e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.47863e-11	AbsError: 5.60049e+02
#       Equation: "PotentialEquation"	RelError: 2.02490e-14	AbsError: 3.61471e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.15983e+01	AbsError: 4.93903e+16
#     Region: "Silicon"	RelError: 1.15983e+01	AbsError: 4.93903e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32506e-01	AbsError: 2.46885e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32505e-01	AbsError: 2.47018e+16
#       Equation: "PotentialEquation"	RelError: 1.07333e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.73045e-01	AbsError: 1.40690e+15
#     Region: "Silicon"	RelError: 3.73045e-01	AbsError: 1.40690e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77706e-01	AbsError: 7.03615e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77705e-01	AbsError: 7.03288e+14
#       Equation: "PotentialEquation"	RelError: 1.76334e-02	AbsError: 4.42630e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.23484e-04	AbsError: 1.69961e+11
#     Region: "Silicon"	RelError: 4.23484e-04	AbsError: 1.69961e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.11182e-04	AbsError: 8.48807e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.11224e-04	AbsError: 8.50798e+10
#       Equation: "PotentialEquation"	RelError: 1.07817e-06	AbsError: 2.89903e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.16609e-11	AbsError: 1.18161e+03
#     Region: "Silicon"	RelError: 3.16609e-11	AbsError: 1.18161e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.58258e-11	AbsError: 5.26920e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.58161e-11	AbsError: 6.54688e+02
#       Equation: "PotentialEquation"	RelError: 1.90336e-14	AbsError: 4.27462e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.49106e+01	AbsError: 5.01770e+16
#     Region: "Silicon"	RelError: 1.49106e+01	AbsError: 5.01770e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32511e-01	AbsError: 2.50886e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32511e-01	AbsError: 2.50884e+16
#       Equation: "PotentialEquation"	RelError: 1.40456e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.80128e-01	AbsError: 1.45660e+15
#     Region: "Silicon"	RelError: 3.80128e-01	AbsError: 1.45660e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77697e-01	AbsError: 7.28516e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77696e-01	AbsError: 7.28079e+14
#       Equation: "PotentialEquation"	RelError: 2.47351e-02	AbsError: 4.52752e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.33341e-04	AbsError: 1.77789e+11
#     Region: "Silicon"	RelError: 4.33341e-04	AbsError: 1.77789e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.15856e-04	AbsError: 8.89169e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.15892e-04	AbsError: 8.88723e+10
#       Equation: "PotentialEquation"	RelError: 1.59350e-06	AbsError: 3.05494e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.39306e-11	AbsError: 1.42342e+03
#     Region: "Silicon"	RelError: 3.39306e-11	AbsError: 1.42342e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.69600e-11	AbsError: 7.38907e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.69589e-11	AbsError: 6.84509e+02
#       Equation: "PotentialEquation"	RelError: 1.16442e-14	AbsError: 4.65137e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.29179e+01	AbsError: 5.10038e+16
#     Region: "Silicon"	RelError: 4.29179e+01	AbsError: 5.10038e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32506e-01	AbsError: 2.55088e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32506e-01	AbsError: 2.54950e+16
#       Equation: "PotentialEquation"	RelError: 4.20528e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 4.34652e-01	AbsError: 1.50967e+15
#     Region: "Silicon"	RelError: 4.34652e-01	AbsError: 1.50967e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77681e-01	AbsError: 7.55109e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77680e-01	AbsError: 7.54557e+14
#       Equation: "PotentialEquation"	RelError: 7.92902e-02	AbsError: 4.63364e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.46857e-04	AbsError: 1.86675e+11
#     Region: "Silicon"	RelError: 4.46857e-04	AbsError: 1.86675e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.20748e-04	AbsError: 9.34357e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.20779e-04	AbsError: 9.32395e+10
#       Equation: "PotentialEquation"	RelError: 5.33093e-06	AbsError: 3.22497e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.64669e-11	AbsError: 1.61738e+03
#     Region: "Silicon"	RelError: 3.64669e-11	AbsError: 1.61738e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.82257e-11	AbsError: 8.44835e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.82321e-11	AbsError: 7.72541e+02
#       Equation: "PotentialEquation"	RelError: 9.13142e-15	AbsError: 5.97139e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 7.85558e+01	AbsError: 5.18835e+16
#     Region: "Silicon"	RelError: 7.85558e+01	AbsError: 5.18835e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32493e-01	AbsError: 2.59467e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32493e-01	AbsError: 2.59368e+16
#       Equation: "PotentialEquation"	RelError: 7.76908e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 5.74143e-01	AbsError: 1.56719e+15
#     Region: "Silicon"	RelError: 5.74143e-01	AbsError: 1.56719e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77660e-01	AbsError: 7.83497e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.77660e-01	AbsError: 7.83697e+14
#       Equation: "PotentialEquation"	RelError: 2.18823e-01	AbsError: 4.74503e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.66903e-04	AbsError: 1.96163e+11
#     Region: "Silicon"	RelError: 4.66903e-04	AbsError: 1.96163e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.25873e-04	AbsError: 9.80921e+10
#       Equation: "HoleContinuityEquation"	RelError: 2.25904e-04	AbsError: 9.80713e+10
#       Equation: "PotentialEquation"	RelError: 1.51262e-05	AbsError: 3.41081e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.92758e-11	AbsError: 1.61048e+03
#     Region: "Silicon"	RelError: 3.92758e-11	AbsError: 1.61048e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.96244e-11	AbsError: 7.72374e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.96265e-11	AbsError: 8.38107e+02
#       Equation: "PotentialEquation"	RelError: 2.48591e-14	AbsError: 3.63915e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.46325e+01	AbsError: 5.28040e+16
#     Region: "Silicon"	RelError: 4.46325e+01	AbsError: 5.28040e+16
# ...
#     Region: "Silicon"	RelError: 3.55379e-01	AbsError: 2.36997e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77302e-01	AbsError: 1.18476e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.77303e-01	AbsError: 1.18522e+15
#       Equation: "PotentialEquation"	RelError: 7.74350e-04	AbsError: 6.06661e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 5.73242e-04	AbsError: 4.13375e+11
#     Region: "Silicon"	RelError: 5.73242e-04	AbsError: 4.13375e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.86567e-04	AbsError: 2.06661e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.86564e-04	AbsError: 2.06714e+11
#       Equation: "PotentialEquation"	RelError: 1.11557e-07	AbsError: 6.15430e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 8.53291e-11	AbsError: 1.05524e+04
#     Region: "Silicon"	RelError: 8.53291e-11	AbsError: 1.05524e+04
#       Equation: "ElectronContinuityEquation"	RelError: 4.26622e-11	AbsError: 5.27689e+03
#       Equation: "HoleContinuityEquation"	RelError: 4.26655e-11	AbsError: 5.27551e+03
#       Equation: "PotentialEquation"	RelError: 1.35703e-15	AbsError: 1.00223e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.18105e+00	AbsError: 6.40422e+16
#     Region: "Silicon"	RelError: 1.18105e+00	AbsError: 6.40422e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32148e-01	AbsError: 3.20170e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32148e-01	AbsError: 3.20252e+16
#       Equation: "PotentialEquation"	RelError: 3.16755e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.55107e-01	AbsError: 2.51079e+15
#     Region: "Silicon"	RelError: 3.55107e-01	AbsError: 2.51079e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77240e-01	AbsError: 1.25530e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.77240e-01	AbsError: 1.25550e+15
#       Equation: "PotentialEquation"	RelError: 6.27811e-04	AbsError: 6.26070e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 5.90961e-04	AbsError: 4.86006e+11
#     Region: "Silicon"	RelError: 5.90961e-04	AbsError: 4.86006e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.95421e-04	AbsError: 2.42995e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.95453e-04	AbsError: 2.43012e+11
#       Equation: "PotentialEquation"	RelError: 8.80060e-08	AbsError: 6.64661e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 9.45009e-11	AbsError: 1.51743e+04
#     Region: "Silicon"	RelError: 9.45009e-11	AbsError: 1.51743e+04
#       Equation: "ElectronContinuityEquation"	RelError: 4.72415e-11	AbsError: 7.58692e+03
#       Equation: "HoleContinuityEquation"	RelError: 4.72581e-11	AbsError: 7.58737e+03
#       Equation: "PotentialEquation"	RelError: 1.34724e-15	AbsError: 1.15852e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.10474e+00	AbsError: 6.58052e+16
#     Region: "Silicon"	RelError: 1.10474e+00	AbsError: 6.58052e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32090e-01	AbsError: 3.29033e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32091e-01	AbsError: 3.29019e+16
#       Equation: "PotentialEquation"	RelError: 2.40557e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.54877e-01	AbsError: 2.66893e+15
#     Region: "Silicon"	RelError: 3.54877e-01	AbsError: 2.66893e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77170e-01	AbsError: 1.33434e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.77170e-01	AbsError: 1.33459e+15
#       Equation: "PotentialEquation"	RelError: 5.37118e-04	AbsError: 6.46713e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 6.09939e-04	AbsError: 5.76379e+11
#     Region: "Silicon"	RelError: 6.09939e-04	AbsError: 5.76379e+11
#       Equation: "ElectronContinuityEquation"	RelError: 3.04938e-04	AbsError: 2.88166e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.04927e-04	AbsError: 2.88213e+11
#       Equation: "PotentialEquation"	RelError: 7.51642e-08	AbsError: 7.19814e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.05073e-10	AbsError: 2.21782e+04
#     Region: "Silicon"	RelError: 1.05073e-10	AbsError: 2.21782e+04
#       Equation: "ElectronContinuityEquation"	RelError: 5.25459e-11	AbsError: 1.10922e+04
#       Equation: "HoleContinuityEquation"	RelError: 5.25257e-11	AbsError: 1.10860e+04
#       Equation: "PotentialEquation"	RelError: 9.40098e-16	AbsError: 1.36854e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.05796e+00	AbsError: 6.76880e+16
#     Region: "Silicon"	RelError: 1.05796e+00	AbsError: 6.76880e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.32027e-01	AbsError: 3.38399e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.32027e-01	AbsError: 3.38481e+16
#       Equation: "PotentialEquation"	RelError: 1.93911e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.54660e-01	AbsError: 2.84789e+15
#     Region: "Silicon"	RelError: 3.54660e-01	AbsError: 2.84789e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77092e-01	AbsError: 1.42376e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.77093e-01	AbsError: 1.42413e+15
#       Equation: "PotentialEquation"	RelError: 4.75510e-04	AbsError: 6.68658e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 6.30030e-04	AbsError: 6.90246e+11
#     Region: "Silicon"	RelError: 6.30030e-04	AbsError: 6.90246e+11
#       Equation: "ElectronContinuityEquation"	RelError: 3.14973e-04	AbsError: 3.45113e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.14989e-04	AbsError: 3.45133e+11
#       Equation: "PotentialEquation"	RelError: 6.73662e-08	AbsError: 7.80888e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.17307e-10	AbsError: 3.30176e+04
#     Region: "Silicon"	RelError: 1.17307e-10	AbsError: 3.30176e+04
#       Equation: "ElectronContinuityEquation"	RelError: 5.86539e-11	AbsError: 1.65099e+04
#       Equation: "HoleContinuityEquation"	RelError: 5.86518e-11	AbsError: 1.65078e+04
#       Equation: "PotentialEquation"	RelError: 9.66048e-16	AbsError: 1.42946e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.02633e+00	AbsError: 6.97705e+16
#     Region: "Silicon"	RelError: 1.02633e+00	AbsError: 6.97705e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31956e-01	AbsError: 3.48884e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31956e-01	AbsError: 3.48821e+16
#       Equation: "PotentialEquation"	RelError: 1.62416e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.54442e-01	AbsError: 3.05183e+15
#     Region: "Silicon"	RelError: 3.54442e-01	AbsError: 3.05183e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.77005e-01	AbsError: 1.52593e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.77005e-01	AbsError: 1.52590e+15
#       Equation: "PotentialEquation"	RelError: 4.31089e-04	AbsError: 6.92006e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 6.51498e-04	AbsError: 8.35293e+11
#     Region: "Silicon"	RelError: 6.51498e-04	AbsError: 8.35293e+11
#       Equation: "ElectronContinuityEquation"	RelError: 3.25714e-04	AbsError: 4.17627e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.25722e-04	AbsError: 4.17666e+11
#       Equation: "PotentialEquation"	RelError: 6.24038e-08	AbsError: 8.48072e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.31343e-10	AbsError: 5.00219e+04
#     Region: "Silicon"	RelError: 1.31343e-10	AbsError: 5.00219e+04
#       Equation: "ElectronContinuityEquation"	RelError: 6.56624e-11	AbsError: 2.50139e+04
#       Equation: "HoleContinuityEquation"	RelError: 6.56794e-11	AbsError: 2.50080e+04
#       Equation: "PotentialEquation"	RelError: 1.05121e-15	AbsError: 1.38603e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.00348e+00	AbsError: 7.20536e+16
#     Region: "Silicon"	RelError: 1.00348e+00	AbsError: 7.20536e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31877e-01	AbsError: 3.60267e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31877e-01	AbsError: 3.60269e+16
#       Equation: "PotentialEquation"	RelError: 1.39723e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.54212e-01	AbsError: 3.28507e+15
#     Region: "Silicon"	RelError: 3.54212e-01	AbsError: 3.28507e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76907e-01	AbsError: 1.64248e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.76907e-01	AbsError: 1.64259e+15
#       Equation: "PotentialEquation"	RelError: 3.97833e-04	AbsError: 7.16734e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 6.74187e-04	AbsError: 1.02315e+12
#     Region: "Silicon"	RelError: 6.74187e-04	AbsError: 1.02315e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.37076e-04	AbsError: 5.11538e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.37052e-04	AbsError: 5.11608e+11
#       Equation: "PotentialEquation"	RelError: 5.90643e-08	AbsError: 9.21191e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.50481e-10	AbsError: 7.70245e+04
#     Region: "Silicon"	RelError: 1.50481e-10	AbsError: 7.70245e+04
#       Equation: "ElectronContinuityEquation"	RelError: 7.52444e-11	AbsError: 3.85108e+04
#       Equation: "HoleContinuityEquation"	RelError: 7.52351e-11	AbsError: 3.85137e+04
#       Equation: "PotentialEquation"	RelError: 1.00569e-15	AbsError: 1.47626e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.86168e-01	AbsError: 7.45694e+16
#     Region: "Silicon"	RelError: 9.86168e-01	AbsError: 7.45694e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31787e-01	AbsError: 3.72831e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31787e-01	AbsError: 3.72862e+16
#       Equation: "PotentialEquation"	RelError: 1.22594e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.53960e-01	AbsError: 3.55688e+15
#     Region: "Silicon"	RelError: 3.53960e-01	AbsError: 3.55688e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76794e-01	AbsError: 1.77859e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.76794e-01	AbsError: 1.77830e+15
#       Equation: "PotentialEquation"	RelError: 3.72107e-04	AbsError: 7.42759e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 6.98096e-04	AbsError: 1.27025e+12
#     Region: "Silicon"	RelError: 6.98096e-04	AbsError: 1.27025e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.49026e-04	AbsError: 6.35141e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.49013e-04	AbsError: 6.35109e+11
#       Equation: "PotentialEquation"	RelError: 5.67191e-08	AbsError: 1.00851e-08
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.71412e-10	AbsError: 1.20112e+05
#     Region: "Silicon"	RelError: 1.71412e-10	AbsError: 1.20112e+05
#       Equation: "ElectronContinuityEquation"	RelError: 8.57050e-11	AbsError: 6.00577e+04
#       Equation: "HoleContinuityEquation"	RelError: 8.57060e-11	AbsError: 6.00547e+04
#       Equation: "PotentialEquation"	RelError: 8.85029e-16	AbsError: 1.61504e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.72576e-01	AbsError: 7.73744e+16
#     Region: "Silicon"	RelError: 9.72576e-01	AbsError: 7.73744e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31685e-01	AbsError: 3.86860e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31685e-01	AbsError: 3.86884e+16
#       Equation: "PotentialEquation"	RelError: 1.09206e-01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.53678e-01	AbsError: 3.87586e+15
#     Region: "Silicon"	RelError: 3.53678e-01	AbsError: 3.87586e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76663e-01	AbsError: 1.93805e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.76663e-01	AbsError: 1.93781e+15
#       Equation: "PotentialEquation"	RelError: 3.51848e-04	AbsError: 7.69933e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 7.23045e-04	AbsError: 1.60044e+12
#     Region: "Silicon"	RelError: 7.23045e-04	AbsError: 1.60044e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.61478e-04	AbsError: 8.00248e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.61512e-04	AbsError: 8.00190e+11
#       Equation: "PotentialEquation"	RelError: 5.47329e-08	AbsError: 1.08530e-08
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.91868e-10	AbsError: 1.88378e+05
#     Region: "Silicon"	RelError: 1.91868e-10	AbsError: 1.88378e+05
#       Equation: "ElectronContinuityEquation"	RelError: 9.59385e-11	AbsError: 9.41931e+04
#       Equation: "HoleContinuityEquation"	RelError: 9.59286e-11	AbsError: 9.41852e+04
#       Equation: "PotentialEquation"	RelError: 9.63227e-16	AbsError: 2.37611e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.61586e-01	AbsError: 8.05272e+16
#     Region: "Silicon"	RelError: 9.61586e-01	AbsError: 8.05272e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31566e-01	AbsError: 4.02646e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31566e-01	AbsError: 4.02626e+16
#       Equation: "PotentialEquation"	RelError: 9.84541e-02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.53350e-01	AbsError: 4.25533e+15
#     Region: "Silicon"	RelError: 3.53350e-01	AbsError: 4.25533e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76507e-01	AbsError: 2.12770e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.76507e-01	AbsError: 2.12763e+15
#       Equation: "PotentialEquation"	RelError: 3.35327e-04	AbsError: 7.97681e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 7.48491e-04	AbsError: 2.04942e+12
#     Region: "Silicon"	RelError: 7.48491e-04	AbsError: 2.04942e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.74202e-04	AbsError: 1.02472e+12
#       Equation: "HoleContinuityEquation"	RelError: 3.74236e-04	AbsError: 1.02470e+12
#       Equation: "PotentialEquation"	RelError: 5.24680e-08	AbsError: 1.13131e-08
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.07692e-10	AbsError: 2.93241e+05
#     Region: "Silicon"	RelError: 2.07692e-10	AbsError: 2.93241e+05
#       Equation: "ElectronContinuityEquation"	RelError: 1.03847e-10	AbsError: 1.46617e+05
#       Equation: "HoleContinuityEquation"	RelError: 1.03842e-10	AbsError: 1.46623e+05
#       Equation: "PotentialEquation"	RelError: 2.35901e-15	AbsError: 6.41158e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 9.52480e-01	AbsError: 8.40997e+16
#     Region: "Silicon"	RelError: 9.52480e-01	AbsError: 8.40997e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.31425e-01	AbsError: 4.20503e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.31425e-01	AbsError: 4.20494e+16
#       Equation: "PotentialEquation"	RelError: 8.96297e-02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.52953e-01	AbsError: 4.71543e+15
#     Region: "Silicon"	RelError: 3.52953e-01	AbsError: 4.71543e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.76316e-01	AbsError: 2.35776e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.76316e-01	AbsError: 2.35766e+15
#       Equation: "PotentialEquation"	RelError: 3.21272e-04	AbsError: 8.24877e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 7.73291e-04	AbsError: 2.66938e+12
#     Region: "Silicon"	RelError: 7.73291e-04	AbsError: 2.66938e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.86603e-04	AbsError: 1.33467e+12
#       Equation: "HoleContinuityEquation"	RelError: 3.86639e-04	AbsError: 1.33471e+12
#       Equation: "PotentialEquation"	RelError: 4.89459e-08	AbsError: 1.14566e-08
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.14470e-10	AbsError: 4.41749e+05
#     Region: "Silicon"	RelError: 2.14470e-10	AbsError: 4.41749e+05
#       Equation: "ElectronContinuityEquation"	RelError: 1.07223e-10	AbsError: 2.20877e+05
#       Equation: "HoleContinuityEquation"	RelError: 1.07242e-10	AbsError: 2.20872e+05
#       Equation: "PotentialEquation"	RelError: 4.58763e-15	AbsError: 1.29764e-15

# %% [markdown]
# ### 13. Energy Band Diagram Under Forward Bias
#
# We now plot the band structure after applying a forward bias of $0.2$ V. In this convention, the electrostatic potential sets the vertical bending of the bands, and the left contact is used as the zero-energy reference.
#
# Because the device is out of equilibrium, the electron and hole populations are described by separate quasi-Fermi levels, $E_{Fn}$ and $E_{Fp}$. Their separation shows how the applied bias drives carrier injection through the junction and lowers the barrier for current flow.

# %%
# Energy band diagram at 0.2 V forward bias

from devsim import get_parameter

voltage = 0.7
set_parameter(device=device, name=top_bias_name, value=voltage)
set_parameter(device=device, name=bottom_bias_name, value=0.0)

solve(
    type="dc",
    absolute_error=1e3,
    relative_error=1e-9,
    maximum_iterations=300,
)

x_cm = np.asarray(get_node_model_values(device=device, region=region, name="x"))
x_um = 1e4 * x_cm

potential = np.asarray(get_node_model_values(device=device, region=region, name="Potential"))
electrons = np.asarray(get_node_model_values(device=device, region=region, name="Electrons"))
holes = np.asarray(get_node_model_values(device=device, region=region, name="Holes"))
intrinsic_electrons = np.asarray(
    get_node_model_values(device=device, region=region, name="IntrinsicElectrons")
)
intrinsic_holes = np.asarray(
    get_node_model_values(device=device, region=region, name="IntrinsicHoles")
)

Eg = 1.12    # silicon band gap, eV
Vt = 0.02585 # thermal voltage, eV

eps = 1e-30
electrons = np.clip(electrons, eps, None)
holes = np.clip(holes, eps, None)
intrinsic_electrons = np.clip(intrinsic_electrons, eps, None)
intrinsic_holes = np.clip(intrinsic_holes, eps, None)

# Quasi-Fermi potentials in DEVSIM's convention
phi_n = -Vt * np.log(electrons / intrinsic_electrons)
phi_p =  Vt * np.log(holes / intrinsic_holes)

# Use the left contact as the zero-energy reference
Eref = phi_n[-1] # the reference is set to the right contact, which is at 0 V

# Energy bands referred to that same reference
Ei = -potential - Eref
Ec = Ei + Eg / 2
Ev = Ei - Eg / 2

# Quasi-Fermi levels, shifted to the same reference
Efn = -phi_n - Eref
Efp = -phi_p - Eref

plt.figure(figsize=(8, 4.5))
plt.plot(x_um, Ec, label=r"$E_c$")
plt.plot(x_um, Ei, label=r"$E_i$")
plt.plot(x_um, Ev, label=r"$E_v$")
plt.plot(x_um, Efn, "--", label=r"$E_{Fn}$")
plt.plot(x_um, Efp, "-.", label=r"$E_{Fp}$")
plt.xlabel("Position (µm)")
plt.ylabel("Energy (eV)")
plt.title("Energy band diagram at 0.2 V forward bias")
plt.grid(False)
plt.legend(loc="lower right", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 3.11520e-14	AbsError: 2.14237e+03
#     Region: "Silicon"	RelError: 3.11520e-14	AbsError: 2.14237e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.48889e-14	AbsError: 1.11870e+03
#       Equation: "HoleContinuityEquation"	RelError: 1.42006e-14	AbsError: 1.02368e+03
#       Equation: "PotentialEquation"	RelError: 2.06255e-15	AbsError: 4.60316e-16
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 5.65355e-15	AbsError: 4.28709e+02
#     Region: "Silicon"	RelError: 5.65355e-15	AbsError: 4.28709e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.19440e-15	AbsError: 2.08813e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.33348e-15	AbsError: 2.19896e+02
#       Equation: "PotentialEquation"	RelError: 1.25667e-16	AbsError: 3.21847e-17

# %% [markdown]
# ### 14. Adding Optical Generation and Generating the Illuminated J–V Curve
#
# We now extend the drift-diffusion model to represent an illuminated diode by adding a **photogeneration source** to the carrier continuity equations. Under illumination, absorbed photons create electron-hole pairs throughout the semiconductor, producing carriers even when no external current is injected.
#
# The continuity equations solved previously are
#
# $$
# \nabla \cdot \mathbf{J}_n
# =
# q\left(R-G\right),
# $$
#
# $$
# \nabla \cdot \mathbf{J}_p
# =
# -q\left(R-G\right),
# $$
#
# where
#
# - $\mathbf{J}_n$ and $\mathbf{J}_p$ are the electron and hole current densities,
# - $R$ is the carrier recombination rate, and
# - $G$ is the carrier generation rate.
#
# In the dark, the generation term is zero,
#
# $$
# G = 0,
# $$
#
# so only recombination contributes to the source terms. To model illumination, we introduce a constant photogeneration rate,
#
# $$
# \boxed{G = G_{\mathrm{photo}},}
# $$
#
# which represents the number of electron-hole pairs created per unit volume per second.
#
# In DEVSIM, this is accomplished by replacing the default source terms with
#
# $$
# \boxed{\texttt{ElectronGeneration} = +q\,G_{\mathrm{photo}}}
# $$
#
# and
#
# $$
# \boxed{\texttt{HoleGeneration} = -q\,G_{\mathrm{photo}}.}
# $$
#
# These two terms are equal in magnitude and opposite in sign because every absorbed photon generates **one electron and one hole**. Consequently, charge is conserved while both carrier populations increase simultaneously.
#
# After introducing these generation terms, we solve the coupled Poisson, electron continuity, and hole continuity equations again to obtain the steady-state illuminated solution. We then perform another voltage sweep by increasing the voltage applied to the top (p-type) contact while keeping the bottom (n-type) contact grounded.
#
# For each applied voltage, the terminal current density is calculated and plotted to produce the illuminated J–V characteristic. Compared with the dark diode, illumination shifts the current-voltage curve downward by the photocurrent, producing a finite short-circuit current at zero bias and, at sufficiently high voltages, an open-circuit voltage where the net current becomes zero.

# %%
from devsim.python_packages.model_create import CreateNodeModel

q = 1.602176634e-19

# Fixed uniform photogeneration rate in the absorber
# Units: cm^-3 s^-1
G_photo = 1.0e21

# Replace the default SRH-based source terms with a constant generation source.
# Signs are chosen to create electron-hole pairs:
#   electrons get +q*G_photo
#   holes get -q*G_photo
CreateNodeModel(device, region, "ElectronGeneration", f"{q}*{G_photo}")
CreateNodeModel(device, region, "HoleGeneration", f"-{q}*{G_photo}")

# Now solve the coupled Poisson + electron continuity + hole continuity
# system for the illuminated case.
# The solution will be the same as the dark case,
# except that the source terms are now non-zero.

solve(
    type="dc",
    absolute_error=1e10,
    relative_error=1e-8,
    maximum_iterations=50,
)

# --- bias sweep ---

top_bias = simple_physics.GetContactBiasName("top")
bot_bias = simple_physics.GetContactBiasName("bot")

set_parameter(device=device, name=bot_bias, value=0.0)

voltages = np.arange(0.0, 0.51, 0.02)
j_light = []

for v in voltages:
    set_parameter(device=device, name=top_bias, value=float(v))

    solve(
        type="dc",
        absolute_error=1e10,
        relative_error=1e-8,
        maximum_iterations=50,

    )

    # choose the sign convention you want for plotting
    current_density = -terminal_current_density("top")
    j_light.append(current_density)

    if current_density < 0:
        break

j_light = np.asarray(j_light)

plt.figure(figsize=(8, 5))
plt.plot(voltages[:len(j_light)], 1e3 * j_light,'-o')
plt.axhline(0, linewidth=0.8)
plt.xlabel("Applied voltage (V)")
plt.ylabel("- Current density (mA/cm$^2$)")
plt.title("Illuminated J-V curve")
plt.grid(True)
plt.show()
# Out:
# Replacing Node Model ElectronGeneration in region Silicon of material Si
# Replacing Node Model HoleGeneration in region Silicon of material Si
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 3.99137e-05	AbsError: 1.22721e+09
#     Region: "Silicon"	RelError: 3.99137e-05	AbsError: 1.22721e+09
#       Equation: "ElectronContinuityEquation"	RelError: 1.31333e-05	AbsError: 6.33569e+08
#       Equation: "HoleContinuityEquation"	RelError: 2.67800e-05	AbsError: 5.93637e+08
#       Equation: "PotentialEquation"	RelError: 4.35256e-10	AbsError: 1.00508e-10
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.80063e-14	AbsError: 5.03353e+02
#     Region: "Silicon"	RelError: 1.80063e-14	AbsError: 5.03353e+02
#       Equation: "ElectronContinuityEquation"	RelError: 7.93248e-15	AbsError: 2.25715e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.96165e-15	AbsError: 2.77638e+02
#       Equation: "PotentialEquation"	RelError: 1.12182e-16	AbsError: 3.45512e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.99863e+03	AbsError: 1.59766e+18
#     Region: "Silicon"	RelError: 1.99863e+03	AbsError: 1.59766e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 7.97908e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 7.99757e+17
#       Equation: "PotentialEquation"	RelError: 6.31009e-01	AbsError: 8.63291e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.99954e+03	AbsError: 7.70871e+17
#     Region: "Silicon"	RelError: 1.99954e+03	AbsError: 7.70871e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.00289e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.70582e+17
#       Equation: "PotentialEquation"	RelError: 1.54478e+00	AbsError: 8.30498e-02
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 5.49619e+02	AbsError: 2.81540e+17
#     Region: "Silicon"	RelError: 5.49619e+02	AbsError: 2.81540e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99991e-01	AbsError: 1.59308e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99991e-01	AbsError: 1.22232e+17
#       Equation: "PotentialEquation"	RelError: 5.47619e+02	AbsError: 7.94473e-02
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.12417e+03	AbsError: 1.75951e+17
#     Region: "Silicon"	RelError: 2.12417e+03	AbsError: 1.75951e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.65842e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.09367e+17
#       Equation: "PotentialEquation"	RelError: 1.26166e+02	AbsError: 7.54578e-02
# Iteration: 4
#   Device: "SiliconSolarCell"	RelError: 1.09643e+03	AbsError: 1.02133e+17
#     Region: "Silicon"	RelError: 1.09643e+03	AbsError: 1.02133e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.96504e-01	AbsError: 1.73468e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 8.47862e+16
#       Equation: "PotentialEquation"	RelError: 9.64320e+01	AbsError: 7.09985e-02
# Iteration: 5
#   Device: "SiliconSolarCell"	RelError: 1.10897e+03	AbsError: 5.28341e+16
#     Region: "Silicon"	RelError: 1.10897e+03	AbsError: 5.28341e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.39676e+15
#       Equation: "HoleContinuityEquation"	RelError: 9.99998e-01	AbsError: 4.64374e+16
#       Equation: "PotentialEquation"	RelError: 1.08972e+02	AbsError: 6.59600e-02
# Iteration: 6
#   Device: "SiliconSolarCell"	RelError: 4.43854e+03	AbsError: 2.97829e+16
#     Region: "Silicon"	RelError: 4.43854e+03	AbsError: 2.97829e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99386e-01	AbsError: 2.61154e+15
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.71713e+16
#       Equation: "PotentialEquation"	RelError: 3.43854e+03	AbsError: 6.01966e-02
# Iteration: 7
#   Device: "SiliconSolarCell"	RelError: 1.18804e+03	AbsError: 1.85588e+16
#     Region: "Silicon"	RelError: 1.18804e+03	AbsError: 1.85588e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.07184e+03	AbsError: 5.97480e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.98157e-01	AbsError: 1.79613e+16
#       Equation: "PotentialEquation"	RelError: 1.15207e+02	AbsError: 5.35129e-02
# Iteration: 8
#   Device: "SiliconSolarCell"	RelError: 1.02088e+03	AbsError: 9.82968e+15
#     Region: "Silicon"	RelError: 1.02088e+03	AbsError: 9.82968e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.98518e-01	AbsError: 6.24735e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.20494e+15
#       Equation: "PotentialEquation"	RelError: 2.08795e+01	AbsError: 4.56537e-02
# Iteration: 9
#   Device: "SiliconSolarCell"	RelError: 1.00082e+03	AbsError: 3.71719e+15
#     Region: "Silicon"	RelError: 1.00082e+03	AbsError: 3.71719e+15
#       Equation: "ElectronContinuityEquation"	RelError: 6.65730e-01	AbsError: 2.25815e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.49138e+15
#       Equation: "PotentialEquation"	RelError: 1.15268e+00	AbsError: 3.63252e-02
# Iteration: 10
#   Device: "SiliconSolarCell"	RelError: 1.45751e+00	AbsError: 1.06955e+15
#     Region: "Silicon"	RelError: 1.45751e+00	AbsError: 1.06955e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.79648e-01	AbsError: 4.26330e+13
#       Equation: "HoleContinuityEquation"	RelError: 9.99994e-01	AbsError: 1.02692e+15
#       Equation: "PotentialEquation"	RelError: 2.77865e-01	AbsError: 2.56287e-02
# Iteration: 11
#   Device: "SiliconSolarCell"	RelError: 1.91780e-01	AbsError: 3.13254e+14
#     Region: "Silicon"	RelError: 1.91780e-01	AbsError: 3.13254e+14
#       Equation: "ElectronContinuityEquation"	RelError: 3.72621e-02	AbsError: 4.90458e+12
#       Equation: "HoleContinuityEquation"	RelError: 1.17395e-01	AbsError: 3.08350e+14
#       Equation: "PotentialEquation"	RelError: 3.71226e-02	AbsError: 1.77023e-02
# Iteration: 12
#   Device: "SiliconSolarCell"	RelError: 3.24061e-02	AbsError: 1.20219e+14
#     Region: "Silicon"	RelError: 3.24061e-02	AbsError: 1.20219e+14
#       Equation: "ElectronContinuityEquation"	RelError: 6.53576e-03	AbsError: 3.83319e+12
#       Equation: "HoleContinuityEquation"	RelError: 1.05147e-03	AbsError: 1.16386e+14
#       Equation: "PotentialEquation"	RelError: 2.48189e-02	AbsError: 2.87744e-06
# Iteration: 13
#   Device: "SiliconSolarCell"	RelError: 1.37280e-07	AbsError: 5.48580e+08
#     Region: "Silicon"	RelError: 1.37280e-07	AbsError: 5.48580e+08
#       Equation: "ElectronContinuityEquation"	RelError: 1.00988e-07	AbsError: 1.61137e+07
#       Equation: "HoleContinuityEquation"	RelError: 3.42403e-08	AbsError: 5.32466e+08
#       Equation: "PotentialEquation"	RelError: 2.05171e-09	AbsError: 1.08313e-11
# Iteration: 14
#   Device: "SiliconSolarCell"	RelError: 1.54217e-13	AbsError: 4.54019e+02
#     Region: "Silicon"	RelError: 1.54217e-13	AbsError: 4.54019e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.40120e-15	AbsError: 2.83189e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.72860e-15	AbsError: 1.70831e+02
#       Equation: "PotentialEquation"	RelError: 1.49087e-13	AbsError: 4.25696e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.71584e+02	AbsError: 4.16597e+16
#     Region: "Silicon"	RelError: 1.71584e+02	AbsError: 4.16597e+16
#       Equation: "ElectronContinuityEquation"	RelError: 2.87477e-01	AbsError: 2.08220e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.83421e-01	AbsError: 2.08377e+16
#       Equation: "PotentialEquation"	RelError: 1.71013e+02	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.39627e-01	AbsError: 9.70712e+14
#     Region: "Silicon"	RelError: 1.39627e-01	AbsError: 9.70712e+14
#       Equation: "ElectronContinuityEquation"	RelError: 6.56967e-02	AbsError: 4.85383e+14
#       Equation: "HoleContinuityEquation"	RelError: 6.34165e-02	AbsError: 4.85329e+14
#       Equation: "PotentialEquation"	RelError: 1.05143e-02	AbsError: 3.43887e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.02431e-04	AbsError: 1.00965e+11
#     Region: "Silicon"	RelError: 1.02431e-04	AbsError: 1.00965e+11
#       Equation: "ElectronContinuityEquation"	RelError: 5.26081e-05	AbsError: 5.03888e+10
#       Equation: "HoleContinuityEquation"	RelError: 4.94955e-05	AbsError: 5.05764e+10
#       Equation: "PotentialEquation"	RelError: 3.27073e-07	AbsError: 1.62742e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.74868e-12	AbsError: 6.92292e+02
#     Region: "Silicon"	RelError: 1.74868e-12	AbsError: 6.92292e+02
#       Equation: "ElectronContinuityEquation"	RelError: 8.98715e-13	AbsError: 3.53858e+02
#       Equation: "HoleContinuityEquation"	RelError: 8.22190e-13	AbsError: 3.38435e+02
#       Equation: "PotentialEquation"	RelError: 2.77781e-14	AbsError: 3.48561e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 3.12180e+01	AbsError: 4.21403e+16
#     Region: "Silicon"	RelError: 3.12180e+01	AbsError: 4.21403e+16
#       Equation: "ElectronContinuityEquation"	RelError: 2.90094e-01	AbsError: 2.10759e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.85929e-01	AbsError: 2.10644e+16
#       Equation: "PotentialEquation"	RelError: 3.06420e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.36243e-01	AbsError: 9.94174e+14
#     Region: "Silicon"	RelError: 1.36243e-01	AbsError: 9.94174e+14
#       Equation: "ElectronContinuityEquation"	RelError: 6.72797e-02	AbsError: 4.96876e+14
#       Equation: "HoleContinuityEquation"	RelError: 6.48949e-02	AbsError: 4.97298e+14
#       Equation: "PotentialEquation"	RelError: 4.06796e-03	AbsError: 3.49796e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.08826e-04	AbsError: 1.04718e+11
#     Region: "Silicon"	RelError: 1.08826e-04	AbsError: 1.04718e+11
#       Equation: "ElectronContinuityEquation"	RelError: 5.60427e-05	AbsError: 5.24299e+10
#       Equation: "HoleContinuityEquation"	RelError: 5.26513e-05	AbsError: 5.22881e+10
#       Equation: "PotentialEquation"	RelError: 1.32468e-07	AbsError: 1.69251e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.01561e-12	AbsError: 7.74966e+02
#     Region: "Silicon"	RelError: 2.01561e-12	AbsError: 7.74966e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.04550e-12	AbsError: 3.85227e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.56617e-13	AbsError: 3.89739e+02
#       Equation: "PotentialEquation"	RelError: 1.34967e-14	AbsError: 3.96406e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.24908e+01	AbsError: 4.26348e+16
#     Region: "Silicon"	RelError: 4.24908e+01	AbsError: 4.26348e+16
#       Equation: "ElectronContinuityEquation"	RelError: 2.92852e-01	AbsError: 2.13141e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.88566e-01	AbsError: 2.13207e+16
#       Equation: "PotentialEquation"	RelError: 4.19094e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.44116e-01	AbsError: 1.01876e+15
#     Region: "Silicon"	RelError: 1.44116e-01	AbsError: 1.01876e+15
#       Equation: "ElectronContinuityEquation"	RelError: 6.89794e-02	AbsError: 5.09398e+14
#       Equation: "HoleContinuityEquation"	RelError: 6.64773e-02	AbsError: 5.09357e+14
#       Equation: "PotentialEquation"	RelError: 8.65913e-03	AbsError: 3.56004e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.16295e-04	AbsError: 1.08581e+11
#     Region: "Silicon"	RelError: 1.16295e-04	AbsError: 1.08581e+11
#       Equation: "ElectronContinuityEquation"	RelError: 5.98544e-05	AbsError: 5.42212e+10
#       Equation: "HoleContinuityEquation"	RelError: 5.61452e-05	AbsError: 5.43602e+10
#       Equation: "PotentialEquation"	RelError: 2.95484e-07	AbsError: 1.76002e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.33709e-12	AbsError: 7.69674e+02
#     Region: "Silicon"	RelError: 2.33709e-12	AbsError: 7.69674e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.22151e-12	AbsError: 3.75698e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.11292e-12	AbsError: 3.93976e+02
#       Equation: "PotentialEquation"	RelError: 2.65931e-15	AbsError: 4.66045e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 7.17537e+01	AbsError: 4.31175e+16
#     Region: "Silicon"	RelError: 7.17537e+01	AbsError: 4.31175e+16
#       Equation: "ElectronContinuityEquation"	RelError: 2.95768e-01	AbsError: 2.15606e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.91346e-01	AbsError: 2.15568e+16
#       Equation: "PotentialEquation"	RelError: 7.11666e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.59581e-01	AbsError: 1.04559e+15
#     Region: "Silicon"	RelError: 1.59581e-01	AbsError: 1.04559e+15
#       Equation: "ElectronContinuityEquation"	RelError: 7.08123e-02	AbsError: 5.23009e+14
#       Equation: "HoleContinuityEquation"	RelError: 6.81818e-02	AbsError: 5.22581e+14
#       Equation: "PotentialEquation"	RelError: 2.05871e-02	AbsError: 3.62398e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.24887e-04	AbsError: 1.12470e+11
#     Region: "Silicon"	RelError: 1.24887e-04	AbsError: 1.12470e+11
#       Equation: "ElectronContinuityEquation"	RelError: 6.41137e-05	AbsError: 5.63422e+10
#       Equation: "HoleContinuityEquation"	RelError: 6.00361e-05	AbsError: 5.61274e+10
#       Equation: "PotentialEquation"	RelError: 7.37015e-07	AbsError: 1.83270e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.79372e-12	AbsError: 6.62431e+02
#     Region: "Silicon"	RelError: 2.79372e-12	AbsError: 6.62431e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.43297e-12	AbsError: 3.59084e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.29995e-12	AbsError: 3.03347e+02
#       Equation: "PotentialEquation"	RelError: 6.08011e-14	AbsError: 4.37928e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.13273e+01	AbsError: 4.36621e+16
#     Region: "Silicon"	RelError: 2.13273e+01	AbsError: 4.36621e+16
#       Equation: "ElectronContinuityEquation"	RelError: 2.98848e-01	AbsError: 2.18334e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.94283e-01	AbsError: 2.18287e+16
#       Equation: "PotentialEquation"	RelError: 2.07342e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.50584e-01	AbsError: 1.07374e+15
#     Region: "Silicon"	RelError: 1.50584e-01	AbsError: 1.07374e+15
#       Equation: "ElectronContinuityEquation"	RelError: 7.27919e-02	AbsError: 5.36896e+14
#       Equation: "HoleContinuityEquation"	RelError: 7.00179e-02	AbsError: 5.36847e+14
#       Equation: "PotentialEquation"	RelError: 7.77450e-03	AbsError: 3.68992e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.33557e-04	AbsError: 1.17068e+11
#     Region: "Silicon"	RelError: 1.33557e-04	AbsError: 1.17068e+11
#       Equation: "ElectronContinuityEquation"	RelError: 6.88778e-05	AbsError: 5.85060e+10
#       Equation: "HoleContinuityEquation"	RelError: 6.43868e-05	AbsError: 5.85615e+10
#       Equation: "PotentialEquation"	RelError: 2.92319e-07	AbsError: 1.90971e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.25743e-12	AbsError: 8.26899e+02
#     Region: "Silicon"	RelError: 3.25743e-12	AbsError: 8.26899e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.69692e-12	AbsError: 4.53914e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.53827e-12	AbsError: 3.72985e+02
#       Equation: "PotentialEquation"	RelError: 2.22365e-14	AbsError: 7.97016e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.20618e+01	AbsError: 4.41949e+16
#     Region: "Silicon"	RelError: 2.20618e+01	AbsError: 4.41949e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.02117e-01	AbsError: 2.20922e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.97395e-01	AbsError: 2.21027e+16
#       Equation: "PotentialEquation"	RelError: 2.14623e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.56677e-01	AbsError: 1.10274e+15
#     Region: "Silicon"	RelError: 1.56677e-01	AbsError: 1.10274e+15
#       Equation: "ElectronContinuityEquation"	RelError: 7.49371e-02	AbsError: 5.51227e+14
#       Equation: "HoleContinuityEquation"	RelError: 7.20045e-02	AbsError: 5.51509e+14
#       Equation: "PotentialEquation"	RelError: 9.73511e-03	AbsError: 3.75924e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.43888e-04	AbsError: 1.21277e+11
#     Region: "Silicon"	RelError: 1.43888e-04	AbsError: 1.21277e+11
#       Equation: "ElectronContinuityEquation"	RelError: 7.42396e-05	AbsError: 6.06391e+10
#       Equation: "HoleContinuityEquation"	RelError: 6.92635e-05	AbsError: 6.06382e+10
#       Equation: "PotentialEquation"	RelError: 3.84893e-07	AbsError: 1.99090e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.84255e-12	AbsError: 7.26720e+02
#     Region: "Silicon"	RelError: 3.84255e-12	AbsError: 7.26720e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.01312e-12	AbsError: 3.84522e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.81524e-12	AbsError: 3.42197e+02
#       Equation: "PotentialEquation"	RelError: 1.41881e-14	AbsError: 3.49263e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.10207e+01	AbsError: 4.47427e+16
#     Region: "Silicon"	RelError: 2.10207e+01	AbsError: 4.47427e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.05597e-01	AbsError: 2.23764e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.00698e-01	AbsError: 2.23662e+16
#       Equation: "PotentialEquation"	RelError: 2.04144e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.62720e-01	AbsError: 1.13290e+15
#     Region: "Silicon"	RelError: 1.62720e-01	AbsError: 1.13290e+15
#       Equation: "ElectronContinuityEquation"	RelError: 7.72733e-02	AbsError: 5.66166e+14
#       Equation: "HoleContinuityEquation"	RelError: 7.41579e-02	AbsError: 5.66732e+14
#       Equation: "PotentialEquation"	RelError: 1.12885e-02	AbsError: 3.83110e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.55571e-04	AbsError: 1.26451e+11
#     Region: "Silicon"	RelError: 1.55571e-04	AbsError: 1.26451e+11
#       Equation: "ElectronContinuityEquation"	RelError: 8.03237e-05	AbsError: 6.32597e+10
#       Equation: "HoleContinuityEquation"	RelError: 7.47770e-05	AbsError: 6.31914e+10
#       Equation: "PotentialEquation"	RelError: 4.69867e-07	AbsError: 2.07922e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 4.59192e-12	AbsError: 8.66525e+02
#     Region: "Silicon"	RelError: 4.59192e-12	AbsError: 8.66525e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.40360e-12	AbsError: 4.44459e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.16667e-12	AbsError: 4.22065e+02
#       Equation: "PotentialEquation"	RelError: 2.16518e-14	AbsError: 4.06028e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.40040e+01	AbsError: 4.53491e+16
#     Region: "Silicon"	RelError: 2.40040e+01	AbsError: 4.53491e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.09303e-01	AbsError: 2.26769e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.04214e-01	AbsError: 2.26722e+16
#       Equation: "PotentialEquation"	RelError: 2.33905e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.72464e-01	AbsError: 1.16532e+15
#     Region: "Silicon"	RelError: 1.72464e-01	AbsError: 1.16532e+15
#       Equation: "ElectronContinuityEquation"	RelError: 7.98332e-02	AbsError: 5.82644e+14
#       Equation: "HoleContinuityEquation"	RelError: 7.65150e-02	AbsError: 5.82678e+14
#       Equation: "PotentialEquation"	RelError: 1.61158e-02	AbsError: 3.90576e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.68981e-04	AbsError: 1.31372e+11
#     Region: "Silicon"	RelError: 1.68981e-04	AbsError: 1.31372e+11
#       Equation: "ElectronContinuityEquation"	RelError: 8.72501e-05	AbsError: 6.55873e+10
#       Equation: "HoleContinuityEquation"	RelError: 8.10241e-05	AbsError: 6.57849e+10
#       Equation: "PotentialEquation"	RelError: 7.07064e-07	AbsError: 2.17236e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 5.59000e-12	AbsError: 1.20325e+03
#     Region: "Silicon"	RelError: 5.59000e-12	AbsError: 1.20325e+03
#       Equation: "ElectronContinuityEquation"	RelError: 2.88777e-12	AbsError: 5.31301e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.60307e-12	AbsError: 6.71949e+02
#       Equation: "PotentialEquation"	RelError: 9.91504e-14	AbsError: 1.00497e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.96613e+01	AbsError: 4.59526e+16
#     Region: "Silicon"	RelError: 1.96613e+01	AbsError: 4.59526e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.13268e-01	AbsError: 2.29725e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.07969e-01	AbsError: 2.29802e+16
#       Equation: "PotentialEquation"	RelError: 1.90401e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.77201e-01	AbsError: 1.19962e+15
#     Region: "Silicon"	RelError: 1.77201e-01	AbsError: 1.19962e+15
#       Equation: "ElectronContinuityEquation"	RelError: 8.26436e-02	AbsError: 6.00120e+14
#       Equation: "HoleContinuityEquation"	RelError: 7.90856e-02	AbsError: 5.99504e+14
#       Equation: "PotentialEquation"	RelError: 1.54720e-02	AbsError: 3.98326e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 1.84059e-04	AbsError: 1.36709e+11
#     Region: "Silicon"	RelError: 1.84059e-04	AbsError: 1.36709e+11
#       Equation: "ElectronContinuityEquation"	RelError: 9.51849e-05	AbsError: 6.84738e+10
#       Equation: "HoleContinuityEquation"	RelError: 8.81573e-05	AbsError: 6.82351e+10
#       Equation: "PotentialEquation"	RelError: 7.16387e-07	AbsError: 2.27273e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 6.66132e-12	AbsError: 8.49461e+02
#     Region: "Silicon"	RelError: 6.66132e-12	AbsError: 8.49461e+02
#       Equation: "ElectronContinuityEquation"	RelError: 3.48015e-12	AbsError: 4.17945e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.13583e-12	AbsError: 4.31516e+02
#       Equation: "PotentialEquation"	RelError: 4.53365e-14	AbsError: 5.75352e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.84830e+01	AbsError: 4.65680e+16
#     Region: "Silicon"	RelError: 1.84830e+01	AbsError: 4.65680e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.17522e-01	AbsError: 2.32815e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.11984e-01	AbsError: 2.32866e+16
#       Equation: "PotentialEquation"	RelError: 1.78535e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.83872e-01	AbsError: 1.23648e+15
#     Region: "Silicon"	RelError: 1.83872e-01	AbsError: 1.23648e+15
#       Equation: "ElectronContinuityEquation"	RelError: 8.57482e-02	AbsError: 6.18475e+14
#       Equation: "HoleContinuityEquation"	RelError: 8.19301e-02	AbsError: 6.18007e+14
#       Equation: "PotentialEquation"	RelError: 1.61936e-02	AbsError: 4.06405e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.01487e-04	AbsError: 1.42856e+11
#     Region: "Silicon"	RelError: 2.01487e-04	AbsError: 1.42856e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.04327e-04	AbsError: 7.14245e+10
#       Equation: "HoleContinuityEquation"	RelError: 9.63678e-05	AbsError: 7.14310e+10
#       Equation: "PotentialEquation"	RelError: 7.92235e-07	AbsError: 2.38048e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 8.00826e-12	AbsError: 1.00598e+03
#     Region: "Silicon"	RelError: 8.00826e-12	AbsError: 1.00598e+03
#       Equation: "ElectronContinuityEquation"	RelError: 4.20498e-12	AbsError: 4.77854e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.79587e-12	AbsError: 5.28126e+02
#       Equation: "PotentialEquation"	RelError: 7.41794e-15	AbsError: 4.67687e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.49106e+01	AbsError: 4.72366e+16
#     Region: "Silicon"	RelError: 1.49106e+01	AbsError: 4.72366e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.22118e-01	AbsError: 2.36240e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.16310e-01	AbsError: 2.36126e+16
#       Equation: "PotentialEquation"	RelError: 1.42722e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 1.89936e-01	AbsError: 1.27537e+15
#     Region: "Silicon"	RelError: 1.89936e-01	AbsError: 1.27537e+15
#       Equation: "ElectronContinuityEquation"	RelError: 8.92002e-02	AbsError: 6.37858e+14
#       Equation: "HoleContinuityEquation"	RelError: 8.50749e-02	AbsError: 6.37507e+14
#       Equation: "PotentialEquation"	RelError: 1.56608e-02	AbsError: 4.14898e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.21566e-04	AbsError: 1.48655e+11
#     Region: "Silicon"	RelError: 2.21566e-04	AbsError: 1.48655e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.14905e-04	AbsError: 7.41988e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.05850e-04	AbsError: 7.44558e+10
#       Equation: "PotentialEquation"	RelError: 8.10187e-07	AbsError: 2.49544e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 9.71133e-12	AbsError: 1.27810e+03
#     Region: "Silicon"	RelError: 9.71133e-12	AbsError: 1.27810e+03
#       Equation: "ElectronContinuityEquation"	RelError: 5.07345e-12	AbsError: 6.61098e+02
#       Equation: "HoleContinuityEquation"	RelError: 4.60730e-12	AbsError: 6.16998e+02
#       Equation: "PotentialEquation"	RelError: 3.05769e-14	AbsError: 1.11415e-16
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.08540e+01	AbsError: 4.79378e+16
#     Region: "Silicon"	RelError: 2.08540e+01	AbsError: 4.79378e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.27081e-01	AbsError: 2.39699e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.20972e-01	AbsError: 2.39679e+16
#       Equation: "PotentialEquation"	RelError: 2.02060e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.07312e-01	AbsError: 1.31655e+15
#     Region: "Silicon"	RelError: 2.07312e-01	AbsError: 1.31655e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.30788e-02	AbsError: 6.58417e+14
#       Equation: "HoleContinuityEquation"	RelError: 8.85740e-02	AbsError: 6.58129e+14
#       Equation: "PotentialEquation"	RelError: 2.56588e-02	AbsError: 4.23743e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.45403e-04	AbsError: 1.55273e+11
#     Region: "Silicon"	RelError: 2.45403e-04	AbsError: 1.55273e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.27150e-04	AbsError: 7.77586e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.16848e-04	AbsError: 7.75145e+10
#       Equation: "PotentialEquation"	RelError: 1.40456e-06	AbsError: 2.61963e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.16730e-11	AbsError: 1.02372e+03
#     Region: "Silicon"	RelError: 1.16730e-11	AbsError: 1.02372e+03
#       Equation: "ElectronContinuityEquation"	RelError: 6.06920e-12	AbsError: 5.67783e+02
#       Equation: "HoleContinuityEquation"	RelError: 5.57171e-12	AbsError: 4.55935e+02
#       Equation: "PotentialEquation"	RelError: 3.21110e-14	AbsError: 3.98211e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.73546e+01	AbsError: 4.86530e+16
#     Region: "Silicon"	RelError: 1.73546e+01	AbsError: 4.86530e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.32486e-01	AbsError: 2.43234e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.26037e-01	AbsError: 2.43296e+16
#       Equation: "PotentialEquation"	RelError: 1.66961e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.14196e-01	AbsError: 1.36030e+15
#     Region: "Silicon"	RelError: 2.14196e-01	AbsError: 1.36030e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.74695e-02	AbsError: 6.80291e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.25200e-02	AbsError: 6.80012e+14
#       Equation: "PotentialEquation"	RelError: 2.42061e-02	AbsError: 4.32974e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 2.72224e-04	AbsError: 1.62647e+11
#     Region: "Silicon"	RelError: 2.72224e-04	AbsError: 1.62647e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.41218e-04	AbsError: 8.13349e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.29605e-04	AbsError: 8.13122e+10
#       Equation: "PotentialEquation"	RelError: 1.40166e-06	AbsError: 2.75426e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.38905e-11	AbsError: 1.16095e+03
#     Region: "Silicon"	RelError: 1.38905e-11	AbsError: 1.16095e+03
#       Equation: "ElectronContinuityEquation"	RelError: 7.17649e-12	AbsError: 5.85149e+02
#       Equation: "HoleContinuityEquation"	RelError: 6.68707e-12	AbsError: 5.75797e+02
#       Equation: "PotentialEquation"	RelError: 2.69430e-14	AbsError: 3.97810e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.14032e+01	AbsError: 4.93903e+16
#     Region: "Silicon"	RelError: 1.14032e+01	AbsError: 4.93903e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.38422e-01	AbsError: 2.46885e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.31546e-01	AbsError: 2.47018e+16
#       Equation: "PotentialEquation"	RelError: 1.07333e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.17083e-01	AbsError: 1.40690e+15
#     Region: "Silicon"	RelError: 2.17083e-01	AbsError: 1.40690e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.02462e-01	AbsError: 7.03615e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.69877e-02	AbsError: 7.03288e+14
#       Equation: "PotentialEquation"	RelError: 1.76334e-02	AbsError: 4.42630e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.02375e-04	AbsError: 1.69961e+11
#     Region: "Silicon"	RelError: 3.02375e-04	AbsError: 1.69961e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.57013e-04	AbsError: 8.48807e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.44283e-04	AbsError: 8.50798e+10
#       Equation: "PotentialEquation"	RelError: 1.07817e-06	AbsError: 2.89903e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.62969e-11	AbsError: 1.33027e+03
#     Region: "Silicon"	RelError: 1.62969e-11	AbsError: 1.33027e+03
#       Equation: "ElectronContinuityEquation"	RelError: 8.35995e-12	AbsError: 6.64993e+02
#       Equation: "HoleContinuityEquation"	RelError: 7.93000e-12	AbsError: 6.65277e+02
#       Equation: "PotentialEquation"	RelError: 6.91515e-15	AbsError: 4.21115e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.47282e+01	AbsError: 5.01770e+16
#     Region: "Silicon"	RelError: 1.47282e+01	AbsError: 5.01770e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.44936e-01	AbsError: 2.50886e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.37613e-01	AbsError: 2.50884e+16
#       Equation: "PotentialEquation"	RelError: 1.40456e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 2.35063e-01	AbsError: 1.45660e+15
#     Region: "Silicon"	RelError: 2.35063e-01	AbsError: 1.45660e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.08231e-01	AbsError: 7.28516e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.02097e-01	AbsError: 7.28079e+14
#       Equation: "PotentialEquation"	RelError: 2.47351e-02	AbsError: 4.52752e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.36469e-04	AbsError: 1.77789e+11
#     Region: "Silicon"	RelError: 3.36469e-04	AbsError: 1.77789e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.74091e-04	AbsError: 8.89169e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.60785e-04	AbsError: 8.88723e+10
#       Equation: "PotentialEquation"	RelError: 1.59350e-06	AbsError: 3.05494e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 1.88646e-11	AbsError: 1.38267e+03
#     Region: "Silicon"	RelError: 1.88646e-11	AbsError: 1.38267e+03
#       Equation: "ElectronContinuityEquation"	RelError: 9.59891e-12	AbsError: 6.69714e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.26088e-12	AbsError: 7.12955e+02
#       Equation: "PotentialEquation"	RelError: 4.82190e-15	AbsError: 4.70008e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.27493e+01	AbsError: 5.10038e+16
#     Region: "Silicon"	RelError: 4.27493e+01	AbsError: 5.10038e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.52211e-01	AbsError: 2.55088e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.44301e-01	AbsError: 2.54950e+16
#       Equation: "PotentialEquation"	RelError: 4.20528e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.02177e-01	AbsError: 1.50967e+15
#     Region: "Silicon"	RelError: 3.02177e-01	AbsError: 1.50967e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.14903e-01	AbsError: 7.55109e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.07985e-01	AbsError: 7.54557e+14
#       Equation: "PotentialEquation"	RelError: 7.92902e-02	AbsError: 4.63364e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 3.74993e-04	AbsError: 1.86675e+11
#     Region: "Silicon"	RelError: 3.74993e-04	AbsError: 1.86675e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.91183e-04	AbsError: 9.34357e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.78479e-04	AbsError: 9.32395e+10
#       Equation: "PotentialEquation"	RelError: 5.33093e-06	AbsError: 3.22497e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.15679e-11	AbsError: 1.47662e+03
#     Region: "Silicon"	RelError: 2.15679e-11	AbsError: 1.47662e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.08870e-11	AbsError: 7.01404e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.06589e-11	AbsError: 7.75220e+02
#       Equation: "PotentialEquation"	RelError: 2.19584e-14	AbsError: 4.75248e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 7.84029e+01	AbsError: 5.18835e+16
#     Region: "Silicon"	RelError: 7.84029e+01	AbsError: 5.18835e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.60318e-01	AbsError: 2.59467e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.51736e-01	AbsError: 2.59368e+16
#       Equation: "PotentialEquation"	RelError: 7.76908e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 4.56272e-01	AbsError: 1.56719e+15
#     Region: "Silicon"	RelError: 4.56272e-01	AbsError: 1.56719e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.22616e-01	AbsError: 7.83497e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.14833e-01	AbsError: 7.83697e+14
#       Equation: "PotentialEquation"	RelError: 2.18823e-01	AbsError: 4.74503e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.18194e-04	AbsError: 1.96163e+11
#     Region: "Silicon"	RelError: 4.18194e-04	AbsError: 1.96163e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.06880e-04	AbsError: 9.80921e+10
#       Equation: "HoleContinuityEquation"	RelError: 1.96188e-04	AbsError: 9.80713e+10
#       Equation: "PotentialEquation"	RelError: 1.51262e-05	AbsError: 3.41081e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.43915e-11	AbsError: 1.53841e+03
#     Region: "Silicon"	RelError: 2.43915e-11	AbsError: 1.53841e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.22631e-11	AbsError: 7.31566e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.21170e-11	AbsError: 8.06849e+02
#       Equation: "PotentialEquation"	RelError: 1.13641e-14	AbsError: 4.38641e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 4.44970e+01	AbsError: 5.28040e+16
#     Region: "Silicon"	RelError: 4.44970e+01	AbsError: 5.28040e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.69369e-01	AbsError: 2.64056e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.60069e-01	AbsError: 2.63983e+16
#       Equation: "PotentialEquation"	RelError: 4.37675e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.81867e-01	AbsError: 1.62949e+15
#     Region: "Silicon"	RelError: 3.81867e-01	AbsError: 1.62949e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.31388e-01	AbsError: 8.14548e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.22765e-01	AbsError: 8.14940e+14
#       Equation: "PotentialEquation"	RelError: 1.27714e-01	AbsError: 4.86210e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.41325e-04	AbsError: 2.06061e+11
#     Region: "Silicon"	RelError: 4.41325e-04	AbsError: 2.06061e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.20138e-04	AbsError: 1.02958e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.12329e-04	AbsError: 1.03103e+11
#       Equation: "PotentialEquation"	RelError: 8.85819e-06	AbsError: 3.61267e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 2.91988e-11	AbsError: 1.66022e+03
#     Region: "Silicon"	RelError: 2.91988e-11	AbsError: 1.66022e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.54688e-11	AbsError: 8.16014e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.36831e-11	AbsError: 8.44210e+02
#       Equation: "PotentialEquation"	RelError: 4.69959e-14	AbsError: 4.91528e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 8.85945e+01	AbsError: 5.37716e+16
#     Region: "Silicon"	RelError: 8.85945e+01	AbsError: 5.37716e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.79393e-01	AbsError: 2.68888e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.69395e-01	AbsError: 2.68828e+16
#       Equation: "PotentialEquation"	RelError: 8.78457e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 4.73468e-01	AbsError: 1.69673e+15
#     Region: "Silicon"	RelError: 4.73468e-01	AbsError: 1.69673e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.40894e-01	AbsError: 8.48359e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.31739e-01	AbsError: 8.48368e+14
#       Equation: "PotentialEquation"	RelError: 2.00835e-01	AbsError: 4.98531e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.70282e-04	AbsError: 2.16523e+11
#     Region: "Silicon"	RelError: 4.70282e-04	AbsError: 2.16523e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.30879e-04	AbsError: 1.08112e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.25901e-04	AbsError: 1.08411e+11
#       Equation: "PotentialEquation"	RelError: 1.35023e-05	AbsError: 3.83306e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 3.64001e-11	AbsError: 1.83967e+03
#     Region: "Silicon"	RelError: 3.64001e-11	AbsError: 1.83967e+03
#       Equation: "ElectronContinuityEquation"	RelError: 1.93556e-11	AbsError: 8.66533e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.70243e-11	AbsError: 9.73136e+02
#       Equation: "PotentialEquation"	RelError: 2.01237e-14	AbsError: 4.71276e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 1.62639e+01	AbsError: 5.47921e+16
#     Region: "Silicon"	RelError: 1.62639e+01	AbsError: 5.47921e+16
#       Equation: "ElectronContinuityEquation"	RelError: 3.90086e-01	AbsError: 2.73991e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.79668e-01	AbsError: 2.73930e+16
#       Equation: "PotentialEquation"	RelError: 1.54942e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.42498e-01	AbsError: 1.76853e+15
#     Region: "Silicon"	RelError: 3.42498e-01	AbsError: 1.76853e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.50381e-01	AbsError: 8.84495e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.41411e-01	AbsError: 8.84037e+14
#       Equation: "PotentialEquation"	RelError: 5.07056e-02	AbsError: 5.11517e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 4.79743e-04	AbsError: 2.28099e+11
#     Region: "Silicon"	RelError: 4.79743e-04	AbsError: 2.28099e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.39731e-04	AbsError: 1.14021e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.36901e-04	AbsError: 1.14078e+11
#       Equation: "PotentialEquation"	RelError: 3.11139e-06	AbsError: 4.07478e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 4.39699e-11	AbsError: 2.21039e+03
#     Region: "Silicon"	RelError: 4.39699e-11	AbsError: 2.21039e+03
#       Equation: "ElectronContinuityEquation"	RelError: 2.27845e-11	AbsError: 1.06824e+03
#       Equation: "HoleContinuityEquation"	RelError: 2.11799e-11	AbsError: 1.14215e+03
#       Equation: "PotentialEquation"	RelError: 5.48890e-15	AbsError: 7.10213e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 5.12346e+01	AbsError: 5.58708e+16
#     Region: "Silicon"	RelError: 5.12346e+01	AbsError: 5.58708e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.00745e-01	AbsError: 2.79392e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.90584e-01	AbsError: 2.79316e+16
#       Equation: "PotentialEquation"	RelError: 5.04433e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 5.04663e-01	AbsError: 1.84710e+15
#     Region: "Silicon"	RelError: 5.04663e-01	AbsError: 1.84710e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.58837e-01	AbsError: 9.23311e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.50960e-01	AbsError: 9.23788e+14
#       Equation: "PotentialEquation"	RelError: 1.94866e-01	AbsError: 5.25200e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 5.04635e-04	AbsError: 2.40660e+11
#     Region: "Silicon"	RelError: 5.04635e-04	AbsError: 2.40660e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.47604e-04	AbsError: 1.20466e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.46075e-04	AbsError: 1.20194e+11
#       Equation: "PotentialEquation"	RelError: 1.09558e-05	AbsError: 4.34025e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 5.08110e-11	AbsError: 2.49722e+03
#     Region: "Silicon"	RelError: 5.08110e-11	AbsError: 2.49722e+03
#       Equation: "ElectronContinuityEquation"	RelError: 2.58430e-11	AbsError: 1.40936e+03
#       Equation: "HoleContinuityEquation"	RelError: 2.48876e-11	AbsError: 1.08786e+03
#       Equation: "PotentialEquation"	RelError: 8.03401e-14	AbsError: 7.03573e-17
# number of equations 1395
# Iteration: 0
#   Device: "SiliconSolarCell"	RelError: 2.08587e+01	AbsError: 5.70119e+16
#     Region: "Silicon"	RelError: 2.08587e+01	AbsError: 5.70119e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.10332e-01	AbsError: 2.85112e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.01350e-01	AbsError: 2.85008e+16
#       Equation: "PotentialEquation"	RelError: 2.00471e+01	AbsError: 2.00000e-02
# Iteration: 1
#   Device: "SiliconSolarCell"	RelError: 3.82749e-01	AbsError: 1.93342e+15
#     Region: "Silicon"	RelError: 3.82749e-01	AbsError: 1.93342e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.65515e-01	AbsError: 9.66788e+14
#       Equation: "HoleContinuityEquation"	RelError: 1.59361e-01	AbsError: 9.66630e+14
#       Equation: "PotentialEquation"	RelError: 5.78726e-02	AbsError: 5.39623e-05
# Iteration: 2
#   Device: "SiliconSolarCell"	RelError: 5.12934e-04	AbsError: 2.54478e+11
#     Region: "Silicon"	RelError: 5.12934e-04	AbsError: 2.54478e+11
#       Equation: "ElectronContinuityEquation"	RelError: 2.55046e-04	AbsError: 1.27380e+11
#       Equation: "HoleContinuityEquation"	RelError: 2.54266e-04	AbsError: 1.27098e+11
#       Equation: "PotentialEquation"	RelError: 3.62262e-06	AbsError: 4.63278e-09
# Iteration: 3
#   Device: "SiliconSolarCell"	RelError: 5.70563e-11	AbsError: 2.88316e+03
#     Region: "Silicon"	RelError: 5.70563e-11	AbsError: 2.88316e+03
#       Equation: "ElectronContinuityEquation"	RelError: 2.87880e-11	AbsError: 1.44117e+03
#       Equation: "HoleContinuityEquation"	RelError: 2.82522e-11	AbsError: 1.44199e+03
#       Equation: "PotentialEquation"	RelError: 1.60685e-14	AbsError: 6.29964e-17

# %% [markdown]
# ### 15. Evaluating Solar Cell Performance
#
# The illuminated J–V curve contains all the information needed to evaluate the performance of a solar cell. From this curve, we can determine several important figures of merit that describe how effectively the device converts incident light into electrical power.
#
# The electrical power density delivered by the solar cell at each operating voltage is
#
# $$
# P(V)=V\,J(V),
# $$
#
# where $V$ is the applied voltage and $J(V)$ is the corresponding current density. Multiplying the voltage by the current density produces the power density, measured in W/cm$^2$. Plotting this quantity as a function of voltage gives the **power curve**, whose maximum corresponds to the optimum operating point of the device.
#
# #### Short-Circuit Current Density ($J_{SC}$)
#
# The **short-circuit current density** is the current delivered when the external terminals are shorted together, so that
#
# $$
# V=0.
# $$
#
# At this operating point,
#
# $$
# J_{SC}=J(0).
# $$
#
# Physically, $J_{SC}$ measures how many photogenerated carriers are successfully collected by the junction before they recombine. It depends primarily on the optical absorption, carrier lifetimes, diffusion lengths, and the efficiency with which carriers are extracted by the built-in electric field.
#
# #### Open-Circuit Voltage ($V_{OC}$)
#
# The **open-circuit voltage** is the voltage developed across the solar cell when no external current is allowed to flow. Mathematically,
#
# $$
# J(V_{OC})=0.
# $$
#
# At open circuit, photogenerated carriers continue to be created, but instead of flowing through an external circuit they accumulate inside the device. This carrier accumulation separates the electron and hole quasi-Fermi levels, producing the photovoltage that opposes the built-in electric field. The value of $V_{OC}$ is therefore determined by the balance between photogeneration and recombination and represents the maximum voltage the solar cell can produce.
#
# Since the simulated voltage points are discrete, the code determines $V_{OC}$ by locating where the current changes sign and performing a linear interpolation between the two neighboring bias points.
#
# #### Maximum Power Point (MPP)
#
# Although the solar cell can produce both voltage and current, it cannot maximize both simultaneously. The useful operating point is the **maximum power point (MPP)**, where the product of voltage and current reaches its largest value,
#
# $$
# P_{MPP}=V_{MPP}J_{MPP}.
# $$
#
# At this point,
#
# - $V_{MPP}$ is the operating voltage,
# - $J_{MPP}$ is the corresponding current density, and
# - $P_{MPP}$ is the maximum electrical power density that can be extracted from the device.
#
# This is the operating condition that practical photovoltaic systems attempt to maintain using **maximum power point tracking (MPPT)** electronics.
#
# #### Fill Factor (FF)
#
# The **fill factor** measures how closely the illuminated J–V curve approaches the ideal rectangular shape. It is defined as
#
# $$
# FF=\frac{V_{MPP}J_{MPP}}
# {V_{OC}J_{SC}}.
# $$
#
# The denominator,
#
# $$
# V_{OC}J_{SC},
# $$
#
# represents the area of the rectangle bounded by the open-circuit voltage and the short-circuit current density, while the numerator is the actual maximum power delivered by the device.
#
# An ideal solar cell would have a fill factor close to one. In real devices, recombination, series resistance, shunt leakage, and non-ideal transport reduce the fill factor by causing the J–V curve to become more rounded.
#
# #### Conversion Efficiency
#
# The overall performance of a solar cell is measured by its **power conversion efficiency**, which is the fraction of the incident optical power converted into useful electrical power,
#
# $$
# \eta=
# \frac{P_{MPP}}
# {P_{in}}
# \times100\%.
# $$
#
# For standard one-sun testing conditions (AM1.5G), the incident optical power density is conventionally taken as
#
# $$
# P_{in}=100\ \mathrm{mW/cm^2}.
# $$
#
# The efficiency therefore combines the effects of the short-circuit current, open-circuit voltage, and fill factor into a single figure of merit,
#
# $$
# \eta=
# \frac{J_{SC}V_{OC}FF}
# {P_{in}}
# \times100\%.
# $$
#
# Increasing any one of these three quantities generally improves the efficiency, although they are often coupled through the underlying semiconductor physics. For example, increasing carrier lifetime may improve both $J_{SC}$ and $V_{OC}$, while excessive series resistance primarily reduces the fill factor.
#
# Finally, the calculated quantities are summarized in a table containing the short-circuit current density, open-circuit voltage, maximum power point coordinates, maximum output power, fill factor, and conversion efficiency. Together, these parameters provide a comprehensive assessment of the photovoltaic performance of the simulated solar cell.

# %%
# Ensure voltages and j_light have the same length after the break in the loop
v_curve = voltages[:len(j_light)]
j_curve = np.asarray(j_light)

# Calculate Power Curve (P = V * J)
power_curve = v_curve * j_curve

# 1. Jsc (Short-circuit current density): Current at 0V
Jsc = j_curve[0]

# 2. Voc (Open-circuit voltage): Voltage at which current is 0
# Find where j_curve crosses zero (from positive to negative)
zero_cross_idx = np.where(np.diff(np.sign(j_curve)))[0]
if zero_cross_idx.size > 0:
    idx1 = zero_cross_idx[0]
    idx2 = idx1 + 1
    V1, V2 = v_curve[idx1], v_curve[idx2]
    J1, J2 = j_curve[idx1], j_curve[idx2]
    # Linear interpolation to find Voc
    Voc = V1 - J1 * (V2 - V1) / (J2 - J1)
else:
    Voc = np.nan # No zero crossing found

# 3. MPP (Maximum Power Point)
mpp_index = np.argmax(power_curve)
P_mpp = power_curve[mpp_index]
V_mpp = v_curve[mpp_index]
J_mpp = j_curve[mpp_index]

# 4. Fill Factor (FF)
FF = P_mpp / (Voc * Jsc) if Voc != 0 and Jsc != 0 else np.nan

# 5. Efficiency
# Assuming standard incident power density for AM1.5G of 100 mW/cm^2 (0.1 W/cm^2)
P_in = 0.1 # W/cm^2
efficiency = (P_mpp / P_in) * 100 if P_in != 0 else np.nan

# Plot Power Curve
plt.figure(figsize=(8, 5))
plt.plot(v_curve, 1e3 * power_curve, '-o', label='Power Curve')
plt.plot(V_mpp, 1e3 * P_mpp, 'ro', label=f'MPP: {V_mpp:.2f}V, {1e3 * J_mpp:.2f}mA/cm$^2$, {1e3 * P_mpp:.2f}mW/cm$^2$')
plt.xlabel("Applied voltage (V)")
plt.ylabel("Power density (mW/cm$^2$)")
plt.title("Illuminated Power Curve")
plt.grid(True)
plt.legend()
plt.show()

# Display Data Table
properties = {
    'Property': ['Jsc', 'Voc', 'V_mpp', 'J_mpp', 'P_mpp', 'Fill Factor', 'Efficiency'],
    'Value': [
        f'{1e3 * Jsc:.2f} mA/cm^2',
        f'{Voc:.3f} V',
        f'{V_mpp:.3f} V',
        f'{1e3 * J_mpp:.3f} mA/cm^2',
        f'{1e3 * P_mpp:.3f} mW/cm^2',
        f'{FF:.3f}',
        f'{efficiency:.2f} %'
    ]
}
df = pd.DataFrame(properties)
print(df.to_string(index=False))
# Out:
#    Property         Value
#         Jsc  1.16 mA/cm^2
#         Voc       0.425 V
#       V_mpp       0.360 V
#       J_mpp 0.992 mA/cm^2
#       P_mpp 0.357 mW/cm^2
# Fill Factor         0.726
#  Efficiency        0.36 %
